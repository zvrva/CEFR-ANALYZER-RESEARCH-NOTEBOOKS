# %%
import requests
import pandas as pd
import time
import re
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
import asyncio
import pandas as pd
from googletrans import Translator

# %%
try:
    df = pd.read_csv('ru_cefr_short.csv')
    print("✅ Файл найден:")
except:
    print("❌ Файл не найден, используем тестовые данные:")
    test_data = {
        'fragment': [
            "Весной, летом и осенью почти каждую субботу он играет в футбол. У них в школе есть футбольная команда. А зимой он играет в хоккей. Ещё мы любим театр.",
            "Вчера я весь вечер повторял грамматику, учил слова. В контрольной работе я сделал 3 ошибки. Питер и Кен написали всё без ошибок. Преподаватель сказал, что они делают большие успехи.",
            "В такой ситуации особенно сложно работающим студентам, которые должны находить время и для учёбы, и для работы. Это нередко вызывает стресс.",
            "Как редкое животное они стоили очень дорого и являлись предметом роскоши. Археологи нашли останки этих животных в развалинах домов богатых людей четвёртого века нашей эры.",
            "Он увлёкся энтомологией ещё мальчиком и в детстве познакомился с основными учёными трудами в этой области.",
            "Так же радиация — это частица, которая летит на огромной скорости. Сама частица может быть почти любой: от атомного ядра до электрона или фотона."
        ],
        'textbook-assigned cefr level': [1, 2, 3, 4, 5, 6]
    }
    df = pd.DataFrame(test_data)

df
# Out:
# ✅ Файл найден:
#                                                fragment  \
# 0     Весной, летом и осенью почти каждую субботу он...
# 1     Все говорят, что мама хорошая хозяйка. А ещё н...
# 2     На каждой двери красные плакаты и красные фона...
# 3     Я считаю деньги, в час обедаю в кафе, а потом ...
# 4     Магазин «Чёрный квадрат» открывается в 9 часов...
# ...                                                 ...
# 7317  Утечка мозгов стала ключевым трендом междунаро...
# 7318  По оценкам менеджеров «Промы», такая ситуация ...
# 7319  Но это не мы, а техно-мемы заполоняют мир благ...
# 7320  Mapillary использует программное обеспечение д...
# 7321  Новое роботакси, разрабатываемое Маском, сможе...
#
#       textbook-assigned cefr level
# 0                                1
# 1                                1
# 2                                1
# 3                                1
# 4                                1
# ...                            ...
# 7317                             6
# 7318                             6
# 7319                             6
# 7320                             6
# 7321                             6
#
# [7322 rows x 2 columns]

# %%
train_texts, val_texts, train_labels, val_labels = train_test_split(
    df['fragment'].values,
    df['textbook-assigned cefr level'].values,
    test_size=0.2,
    random_state=42,
    stratify=df['textbook-assigned cefr level']
)

len(train_texts)
# Out:
# 5857

# %%
texts_to_augment = []

for i in range(len(train_labels)):
  if train_labels[i] == 6:
    texts_to_augment.append(train_texts[i])


len(texts_to_augment)
# Out:
# 120

# %%
async def main():
    print(f"Аугментируем {len(texts_to_augment)} текстов...")
    df_pred = pd.DataFrame(columns=['text', 'augmented-text'])

    translator = Translator()

    translated_to = await translator.translate(texts_to_augment, src='ru', dest='hi')
    print("Переведено на хинди")

    translated_to = await translator.translate([trans.text for trans in translated_to], src='hi', dest='cs')
    print("Переведено на чешский")
    
    translated_to = await translator.translate([trans.text for trans in translated_to], src='cs', dest='bg')
    print("Переведено на болгарский")
    
    translated_to = await translator.translate([trans.text for trans in translated_to], src='bg', dest='fi')
    print("Переведено на финский")

    translated_to = await translator.translate([trans.text for trans in translated_to], src='fi', dest='tg')
    print("Переведено на таджикский")

    translated_to = await translator.translate([trans.text for trans in translated_to], src='tg', dest='de')
    print("Переведено на немецкий")

    translated_to = await translator.translate([trans.text for trans in translated_to], src='de', dest='et')
    print("Переведено на эстонский")
    
    translated_to = await translator.translate([trans.text for trans in translated_to], src='et', dest='ru')
    print("Переведено обратно на русский")

    for n in range(len(texts_to_augment)):
        print(f"\n{n}. Реальный текст:\n\t{texts_to_augment[n]}")
        print(f"Аугметированный текст:\n\t{translated_to[n].text}")

        new_row = pd.DataFrame({
            'text': [texts_to_augment[n]],
            'augmented-text': [translated_to[n].text]
        })
        df_pred = pd.concat([df_pred, new_row], ignore_index=True)

    output_filename = "c2_augmented_seven_times_translated.csv"
    df_pred.to_csv(output_filename, index=False, encoding='utf-8-sig')


    return df_pred

df_pred = await main()
# Out:
# Аугментируем 120 текстов...
# Переведено на хинди
# Переведено на чешский
# Переведено на болгарский
# Переведено на финский
# Переведено на таджикский
# Переведено на немецкий
# Переведено на эстонский
# Переведено обратно на русский
#
# 0. Реальный текст:
# 	3:38–3:54 Собственно, сама по себе радиация незаразна. Например, мощными дозами излучения от тех же самых изотопов часто стерилизуют фрукты и овощи, а также лечат людей.
# Аугметированный текст:
# 	3:38-3:54 На самом деле само излучение безвредно. Например, излучение одних и тех же изотопов в больших количествах часто стерилизует фрукты и овощи и лечит людей.
#
# 1. Реальный текст:
# 	Недавно компания Uber объявила об инвестиции одного миллиарда долларов в собственную систему автоматизированного вождения, а компания Waymo даже запустила приложение на Android для владельцев их самоуправляемых машин.
# Аугметированный текст:
# 	Uber недавно объявил об инвестициях в миллиард долларов в свою систему беспилотного вождения, а Waymo даже выпустила приложение для Android для владельцев беспилотных автомобилей.
#
# 2. Реальный текст:
# 	Множество повестей: «Двойник», «Дядюшкин сон», «Записки из подполья» и другие, рассказы, публицистика, дневники, даже стихи были в творчестве великого автора.
# Аугметированный текст:
# 	В произведения великого писателя вошли несколько рассказов: «Дудогна», «Сын Дядюшкина», «Подземные записи» и др., рассказы, публицистика, дневники и даже стихи.
#
# 3. Реальный текст:
# 	Встречи одноклассников и одногруппников превращаются в вечеринки понтов, одни рвутся туда – доложить о своей крутизне, другие прячутся на илистом дне – нечем козырнуть. Жить мнением других.
# Аугметированный текст:
# 	Одноклассники и одноклассники превращаются в понтон, один мчится туда — раскрыть свою глупость, другой прячется на дневной платформе, что есть нечего. Живите с мнением других людей.
#
# 4. Реальный текст:
# 	Самопрезентация — как главная черта времени и наша неизлечимая болезнь. Люди хотят отражаться удачливыми в глазах друг друга. Они презентуют миру своё благополучие. Самопрезентация, хоть слово дико, порабощает всех подряд.
# Аугметированный текст:
# 	Самосознание – как основная линия времени и наша неизлечимая болезнь. Люди хотят, чтобы успех отражался в их глазах. Они представляют свое благополучие миру. Самоэффективность помогает каждому, даже если это расплывчатое слово.
#
# 5. Реальный текст:
# 	Откровенность перед собой – это, наверное, умение прятать в сердце горечь, беречь и накапливать опыты и образы, которые никогда никому не передашь.
# Аугметированный текст:
# 	Быть открытым самому себе может означать хранить в своем сердце тепло, боль, переживания и образы, которыми вы не можете поделиться ни с кем.
#
# 6. Реальный текст:
# 	«Сразу после несчастного случая я вспомнил про видео с какими-то невероятными протезами — ловкими, красивыми, управляемыми силой мысли.»
# Аугметированный текст:
# 	— Сразу после аварии я вспомнил видео о невероятных протезах — умных, красивых, управляемых мыслью.
#
# 7. Реальный текст:
# 	Я не хочу думать о своей инвалидности, но это не значит, что я избегаю разговоров о ней.
# Аугметированный текст:
# 	Я не хочу думать о своей инвалидности, но это не значит, что я избегаю об этом говорить.
#
# 8. Реальный текст:
# 	Ведь несмотря на множество программ, олимпиад и рекламы, увы, до сих пор для многих детей инвалиды подобны инопланетным существам!
# Аугметированный текст:
# 	Потому что, несмотря на множество шоу, олимпиад и рекламы, для многих детей с ограниченными возможностями они как чужие!
#
# 9. Реальный текст:
# 	Директор Института социального анализа и прогнозирования РАНХиГС Татьяна Малева объясняет, что в мире сегодня действительно обострилась конкуренция за человеческий капитал, это основной ресурс и мотор развития.
# Аугметированный текст:
# 	Татьяна Малеева, директор НИИ социального анализа и прогнозирования РНЦИГС, говорит, что в современном мире действительно обострилась конкуренция за человеческий капитал, он является основным источником и двигателем развития.
#
# 10. Реальный текст:
# 	Почему мы ещё долго не увидим самоуправляемые машины на дорогах? Новости о достижениях автомобильной промышленности и открытия в сфере искусственного интеллекта создают впечатление, что автоуправляемые машины вот-вот появятся на дорогах.
# Аугметированный текст:
# 	Почему мы уже давно не видим беспилотные автомобили на дорогах? Сообщения о достижениях в автомобильной промышленности и искусственном интеллекте создают впечатление, что беспилотные автомобили появятся в любой момент.
#
# 11. Реальный текст:
# 	0:25–1:24 Большинство людей при этом слове впадает в панику, но на самом деле, мы окружены радиацией со всех сторон. Её излучают небо, земля, дома, другие люди и даже бананы!
# Аугметированный текст:
# 	0:25-1:24 Большинство людей паникуют при этом слове, но на самом деле мы окружены радиацией со всех сторон. Он опрыскивает небо, землю, дом, других людей и даже бананы!
#
# 12. Реальный текст:
# 	Эти изображения люди снимают на смартфоны. В отличие от Street View от Google, который совершенствуется каждые пару лет, карты на платформе Mapillary обновляются каждый день.
# Аугметированный текст:
# 	Люди делают эти фотографии на смартфоны. В отличие от Google Street View, который совершенствуется каждые несколько лет, карты на платформе Mapillary обновляются ежедневно.
#
# 13. Реальный текст:
# 	Вообще многие факты из жизни великого классика так или иначе описаны в его произведениях. Например, страсть Достоевского к рулетке легла в основу романа «Игрок».
# Аугметированный текст:
# 	На самом деле многие факты из жизни великого классика так или иначе описаны в его произведениях. Например, страсть Достоевского к рулетке лежит в основе романа «Игрок».
#
# 14. Реальный текст:
# 	Богатеть, жрать, гулять, жениться на молодой и красивой – лишь бы другие оценили. И даже притворяться богатым, здоровым и весёлым. Наконец, нагреть руки на мнимостях.
# Аугметированный текст:
# 	Богатейте, старейте, танцуйте, выходите замуж молодыми и красивыми – только если это оценят другие. И даже притворяются богатыми, здоровыми и счастливыми. Наконец он получил деньги.
#
# 15. Реальный текст:
# 	Иногда эти частицы-пули сталкиваются с атомами с такой силой, что выбивают из них электроны. Вот почему радиация называется «ионизирующее излучение».
# Аугметированный текст:
# 	Иногда эти группы частиц сталкиваются с атомами с такой силой, что выбрасывают электроны. Поэтому излучение называют ионизирующим излучением.
#
# 16. Реальный текст:
# 	Но технические, нормативные и этические препятствия всё ещё мешают их распространению. Почему мы ещё не готовы к беспилотникам? В апреле 2019 года Илон Маск анонсировал создание роботакси Tesla.
# Аугметированный текст:
# 	Однако технические, юридические и этические препятствия препятствуют их распространению. Почему мы еще не готовы к дронам? В апреле 2019 года Илон Маск объявил, что будет построен робот-такси Tesla.
#
# 17. Реальный текст:
# 	Исследователи пока только мечтают о будущем, в котором самоуправляемые автомобили смогут быть не только потребителями, но и производителями данных о дороге, снимая изображения улиц во время движения.
# Аугметированный текст:
# 	Исследователи все еще мечтают о будущем, в котором беспилотные автомобили не только создают потребителей, но также собирают данные о дорожном движении и делают снимки дороги во время вождения.
#
# 18. Реальный текст:
# 	Утечка мозгов стала ключевым трендом международной миграции последних лет, уверены западные эксперты. На днях ВОИС обнародовала исследование, подтверждающее эту тенденцию и к тому же содержащее парадоксальные открытия.
# Аугметированный текст:
# 	Западные эксперты говорят, что утечка мозгов стала основной тенденцией международной миграции в последние годы. Недавно VOIS опубликовала исследование, подтверждающее эту тенденцию, а также содержащее некоторые парадоксальные наблюдения.
#
# 19. Реальный текст:
# 	Как измерить мем и как зафиксировать факт его самовоспроизведения, передачи и распространения? Как правильно описать мем и определить его содержание? Вторая проблема связана с определением мема.
# Аугметированный текст:
# 	Как она измеряется и как корректируется факт произвола, передачи и распределения? Как правильно его описать и определить содержание? Другая проблема касается определения мема.
#
# 20. Реальный текст:
# 	«Человек без тайности – пустая грамота» – есть такая пословица. Между тем скоростной ритм требует не только лаконичности и цепляющей броскости суждений, но и их частоты.
# Аугметированный текст:
# 	«Человек без тайн — чистый лист», — говорят они. При этом быстрый ритм требует не только краткости и интересной скорости предложений, но и их частоты.
#
# 21. Реальный текст:
# 	Ведь в будущем новым приёмам придётся научиться не только самоуправляемым машинам, но и нам самим, чтобы удерживать созданную технику под контролем.
# Аугметированный текст:
# 	В будущем беспилотным автомобилям придется не только осваивать новые инновации, но и нам придется контролировать создаваемые технологии.
#
# 22. Реальный текст:
# 	В Пока ни один из изобретённых человеком протезов не может полностью заменить руку. Это особенно очевидно, когда необходимо совершить сложную манипуляцию — завязать шнурки, почистить картошку, достать карточку из кошелька.
# Аугметированный текст:
# 	Пока ни один изобретенный человеком протез не может полностью заменить руку. Особенно это необходимо при сложной обработке – завязывании ниток, чистке карты, извлечении карты из мешочка.
#
# 23. Реальный текст:
# 	Фёдор Михайлович Достоевский родился 11 ноября 1821 года в Москве, в дворянской семье. В 16 лет Фёдор с братом переезжает в Петербург и поступает в военно-инженерное училище.
# Аугметированный текст:
# 	Федор Михайлович Достоевский родился 11 ноября 1821 года в Москве в царской семье. В 16 лет Федор с братом поехали в Санкт-Петербург работать в военно-инженерном училище.
#
# 24. Реальный текст:
# 	Идеалом ума, рассматривающего действительность, есть простота, полная ясность, полное понимание. Хорошо известно, что до тех пор, пока вы предмет не постигли, он для вас представляется сложным и туманным.
# Аугметированный текст:
# 	Идеал разума, воспринимающего реальность, — это простота, полная ясность и полное понимание. Мы знаем, что это кажется сложным и неясным, пока вы не вникнете в него.
#
# 25. Реальный текст:
# 	Первый нобелевский лауреат из России, выдающийся учёный, гордость отечественной науки и «первый физиолог мира», как назвали его коллеги на одном из международных съездов.
# Аугметированный текст:
# 	На международном конгрессе его коллеги назвали первого российского нобелевского лауреата, выдающегося учёного, гордость отечественной науки и «первого в мире физиолога».
#
# 26. Реальный текст:
# 	Уменьшить или увеличить эту «ограниченность» — вот и всё, что нам доступно. Но полностью её снять, увы, мы не можем».
# Аугметированный текст:
# 	Увеличить или уменьшить этот «лимит» — это все, что у нас есть. Но мы не можем устранить его полностью.
#
# 27. Реальный текст:
# 	Радиоактивный камень, бетон и кирпич, из которых сделаны наши дома (70), но это ерунда! От калия в нашем собственном теле мы ежедневно получаем дозу ещё в шесть раз больше (390).
# Аугметированный текст:
# 	Радиоактивный камень, бетон и кирпичи, из которых построены наши дома (70), но это ерунда! Каждый день мы усваиваем в организме в шесть раз больше калия (390).
#
# 28. Реальный текст:
# 	Но учёбой он интересуется мало, а больше читает книги зарубежных и русских авторов. В 1844 году Фёдор Михайлович Достоевский начинает свою литературную деятельность: выходит его роман «Бедные люди».
# Аугметированный текст:
# 	Однако он меньше интересуется обучением и в основном читает книги зарубежных и российских авторов. В 1844 году Федор Михайлович Достоевский начал свою литературную деятельность: был опубликован его роман «Бедные люди».
#
# 29. Реальный текст:
# 	Рекламирует свою продукцию, наведывается к потенциальным заказчикам. Словом, работает не покладая рук. Вот-вот, кажется, и покупателей не останется — ведь жалюзи служат долго. За то и любимы в народе.
# Аугметированный текст:
# 	Рекламируйте свою продукцию, привлекайте потенциальных клиентов. Короче говоря, работает без рук. Иногда кажется, что покупателей больше нет – ведь продавцы уже давно заработали. Вот почему люди любят нас.
#
# 30. Реальный текст:
# 	Однако возникает достаточно много вопросов и проблем, связанных с применением меметики и её дальнейшим оформлением в науку. Первая — проблема измерения.
# Аугметированный текст:
# 	Однако применение и дальнейшее развитие меметики в науке вызывает ряд вопросов и проблем. Во-первых, это одно из измерений проблемы.
#
# 31. Реальный текст:
# 	Но конечная цель проекта художника кажется не столько практической, сколько концептуальной: Брайдл исследует, что происходит, когда в общество внедряются потенциально опасные или разрушительные технологии.
# Аугметированный текст:
# 	Но конечная цель проекта художника менее практична и концептуальна: Брайдл исследует, что происходит, когда в общество внедряются потенциально опасные или разрушительные технологии.
#
# 32. Реальный текст:
# 	Ежегодно в мире проводят более миллиона ампутаций. Самая частая причина — диабет и сосудистые заболевания, а также травмы. В России в протезах рук и ног нуждается около 200 тысяч человек.
# Аугметированный текст:
# 	Ежегодно во всем мире проводится более миллиона ампутаций. Наиболее частыми причинами являются сахарный диабет, а также сосудистые заболевания и травмы сосудов. Около 200 тысяч человек в России нуждаются в протезах.
#
# 33. Реальный текст:
# 	Рано или поздно, осознанно либо на инстинктивном уровне человек стремится к созданию семьи. Слово «инстинкт» здесь означает биологическую обусловленность потребности в сохранении и увеличении популяции.
# Аугметированный текст:
# 	Рано или поздно, сознательно или неосознанно, человек пытается создать семью. Слово «стремление» здесь относится к биологически обусловленной потребности в поддержании и росте популяции.
#
# 34. Реальный текст:
# 	Например, радиоизотопы, которые стреляют альфа- и бета-излучением, не могут пробить даже наружный слой кожи или пару сантиметров воздуха.
# Аугметированный текст:
# 	Например, радиоизотопы, испускающие альфа- и бета-излучение, не могут проникнуть даже через внешний слой кожи или через несколько сантиметров воздуха.
#
# 35. Реальный текст:
# 	По его словам, у протезов есть свои плюсы: например, не мёрзнут руки на морозе, и можно взять горячую кастрюлю и чайник, не опасаясь обжечься.
# Аугметированный текст:
# 	По его словам, у искусственных вещей есть свои преимущества: например, на морозе не мерзнут руки и можно брать с собой горячие кастрюли, не обжигаясь.
#
# 36. Реальный текст:
# 	– Она практически заглохла, а вернулись лишь немногие люди пожилого возраста, которые уже не могут создавать ВВП или участвовать в конкуренции за интеллектуальное лидерство.
# Аугметированный текст:
# 	- Оно практически исчезло, и вернулись лишь немногие старики, которые уже не способны производить ВВП или участвовать в конкуренции интеллектуального лидера.
#
# 37. Реальный текст:
# 	По этому показателю оценивается уровень университетов. И вот отечественные ректоры заинтересованы в том, чтобы отправить студентов и аспирантов за границу, но нет никаких гарантий, что те вернутся домой.
# Аугметированный текст:
# 	Этот показатель оценивает уровень вузов. А отечественные лидеры заинтересованы в отправке студентов и специалистов за границу, но не гарантируют их возвращение в страну.
#
# 38. Реальный текст:
# 	Люди привыкают транслировать каждый свой чих, как будто это прибавляет им общественного веса или как будто они сомневаются в том, существуют ли они на самом деле.
# Аугметированный текст:
# 	Люди склонны высказывать все свои мнения так, как будто это увеличивает их общественный вес или как будто они сомневаются в своем существовании.
#
# 39. Реальный текст:
# 	Маршрут задаётся через планшет. Поехали! 00:01:00 Смотрите, как ловко обходит препятствия. Пешеходы на нерегулируемом переходе, как раз тут срабатывают датчики дальнего действия.
# Аугметированный текст:
# 	Маршрут указан через планшет. Водитель! 00:01:00 Наблюдайте, как охотник обходит препятствия. Пешеходы на нерегулируемых пешеходных переходах иногда срабатывают датчики движения.
#
# 40. Реальный текст:
# 	«Хорошие» мемы — это такие, которые обладают высокой выживаемостью в культурной среде, то есть привлекательны для людей, которые с готовностью копируют их на протяжении многих поколений.
# Аугметированный текст:
# 	«Хорошие» мемы — это те, которые имеют высокую выживаемость в культурной среде, то есть привлекают людей, которые любят копировать их из поколения в поколение.
#
# 41. Реальный текст:
# 	Объяснение простое: население там большое, а образовательный уровень граждан в целом довольно высок и продолжает расти, то есть уехавших есть, кем заменить.
# Аугметированный текст:
# 	Объяснение простое: население велико, а уровень образования граждан, как правило, очень высок и продолжает расти, в результате чего многие остаются в нищете.
#
# 42. Реальный текст:
# 	Но писателя не казнят, а смертную казнь в последнюю минуту заменяют Сибирской каторгой в Омске.
# Аугметированный текст:
# 	Писатель остался невиновным, но в последний момент его смертный приговор был заменен тюрьмой в Омске.
#
# 43. Реальный текст:
# 	Меня утешает вот что: где есть зависимость, там есть и боль. Не всякий человек может пребывать всё время на открытом солнцепёке, лишённый тени одиночества.
# Аугметированный текст:
# 	Меня это беспокоит: где зависимость, там и боль. Не каждый может постоянно находиться под открытым солнцем, не чувствуя себя одиноким.
#
# 44. Реальный текст:
# 	Эти сюжеты известны ещё с античности и связаны с природой человека, но интернет придал им размах, а современные психологи возвели в доблесть.
# Аугметированный текст:
# 	Эти виды деятельности известны с древнейших времен и связаны с природой человека. Однако они были опубликованы в Интернете, и сегодняшние психологи обеспокоены их ценностью.
#
# 45. Реальный текст:
# 	Искусство по природе своей мистериально — обращено к глубинам человеческой психики, и поэтому сила его воздействия неисчерпаема, как неисчерпаемы смыслы метафор и образов, средствами которых оно выражает себя.
# Аугметированный текст:
# 	Искусство по своей природе загадка – оно канло в самую глубину человеческой психики и потому его влияние безгранично, бесконечен смысл притч и образов, их средства выражения.
#
# 46. Реальный текст:
# 	По оценкам менеджеров «Промы», такая ситуация абсолютно нереальна, так как потенциал рынка жалюзи в России едва ли не в тысячу раз превышает нынешний ежемесячный объём их продаж.
# Аугметированный текст:
# 	По мнению менеджеров «Знаменитости», такая ситуация совершенно нереальна, поскольку потенциал рынка России в тысячу раз превышает текущий ежемесячный оборот.
#
# 47. Реальный текст:
# 	Основные покупатели таких машин — предприятия и промышленное производство. Как можно решить проблему? Помочь беспилотным автомобилям более безопасно ориентироваться в наших городах смогут краудсорсинговые карты.
# Аугметированный текст:
# 	Основными покупателями этих машин являются компании и промышленные производства. Как мы можем решить проблему? Карты, созданные на основе нескольких карт, помогают беспилотным автомобилям более безопасно перемещаться по нашим городам.
#
# 48. Реальный текст:
# 	Молчат о своих страстях, страхах и о своих надеждах, смешных и прекрасных. Молчат о стыде, неуверенности, об унижениях, о болезнях. Они хвастают пороками, часто преувеличенными.
# Аугметированный текст:
# 	Расскажите о своих страстях, страхах и надеждах, смешно и красиво. Поговорите о застенчивости, неуверенности в себе, издевательствах и болезнях. Они ничем не хвастаются, зачастую слишком сильно.
#
# 49. Реальный текст:
# 	Первое, самое общее свойство, качество ума — это постоянное сосредоточение мысли на определённом вопросе, предмете. С предметом, в области которого вы работаете, вы не должны расставаться ни на минуту.
# Аугметированный текст:
# 	Первое, самое распространенное качество, качество ума – это постоянная концентрация мысли на вопросе, на определенном объекте. Ни на минуту не следует отклоняться от темы.
#
# 50. Реальный текст:
# 	Взяв древнегреческое слово «μιμητής» («миметес»), что означает «подражатель, имитатор», Докинз для удобства отсёк первый слог от его производного «мимем» и получил слово «мем».
# Аугметированный текст:
# 	Благодаря древнегреческому слову «μιμετης» («миμετες»), которое означает «подражатель, подражатель», для простоты берется первый слог каждого «мимема» и получается слово «мем».
#
# 51. Реальный текст:
# 	Павлова называли «романтической, почти легендарной личностью», «гражданином мира», а друг учёного, писатель Герберт Уэллс, сказал о нём: «Это звезда, которая освещает мир, проливая свет на ещё не изведанные пути».
# Аугметированный текст:
# 	Павлова называли «романтическим, почти мифическим городом», «гражданином мира», другой учёный, писатель Герберт Уэллс говорил о нём: «Эта звезда, освещающая мир, освещает ещё не открытые дороги».
#
# 52. Реальный текст:
# 	Пока беспилотные машины существуют в бета-версии, исследователи работают над системами, способными анализировать дорогу лучше, чем водитель-человек.
# Аугметированный текст:
# 	Хотя беспилотные автомобили находятся в стадии бета-тестирования, исследователи работают над системами, которые смогут анализировать дорогу лучше, чем водитель-человек.
#
# 53. Реальный текст:
# 	Славный парень, недавно уволенный с ТВ, спешит сообщить, что он на Лазурном Берегу, и вывесить фотографию откупоренной бутылки шампанского. 70 лайков за 15 минут! 300 за час!
# Аугметированный текст:
# 	Недавно уволенная с телевидения красотка сразу же объявляет, что она на Французской Ривьере, и публикует фотографию разбитой бутылки шампанского. 70 лайков за 15 минут! 300 в час!
#
# 54. Реальный текст:
# 	Почему машины не готовы принимать «разумные» решения? Ещё одна нерешённая проблема заключается в создании системы, которая может принимать разумные решения — регулировать скорость и менять полосы движения.
# Аугметированный текст:
# 	Почему машины не готовы принимать «разумные» решения? Еще одна нерешенная проблема — создание системы, принимающей интеллектуальные решения — контроля скорости и смены полосы движения.
#
# 55. Реальный текст:
# 	Уже к середине следующего года глава компании собирается выпустить на дороги США более миллиона полностью беспилотных машин. Понятие «автопилот» компания Tesla начала использовать для своих электромобилей ещё в 2015 году.
# Аугметированный текст:
# 	Босс компании хочет, чтобы к середине следующего года на американских дорогах было более миллиона полностью автономных автомобилей. В 2015 году Tesla представила концепцию автопилота в своих электромобилях.
#
# 56. Реальный текст:
# 	Действительность велика, беспредельна, бесконечна и разнообразна, она никогда не укладывается в рамки наших признанных понятий, наших самых последних знаний.
# Аугметированный текст:
# 	Реальность огромна, безгранична, бесконечна и многослойна, ее никогда нельзя включить в наши принятые понятия, в наши новейшие знания.
#
# 57. Реальный текст:
# 	Но многие ли знают, что мемами интересуются сразу два направления в науке — мемология и меметика? И почему представители обоих говорят о том, что мы сегодня переживаем настоящую «мем-революцию»?
# Аугметированный текст:
# 	Но многие ли знают, что мемами интересуются одновременно две научные области — мемология и меметика? И почему представители тех и других говорят о том, что у нас сегодня настоящая «революция мемов»?
#
# 58. Реальный текст:
# 	Даже тонкие интеллектуалы и изящные эстеты не забудут с ненавязчивой гордыней сообщить о свежих итальянских путешествиях, и освежающие брызги ворвутся в их высокую речь.
# Аугметированный текст:
# 	Даже бывалые интеллектуалы и элегантные эстеты с гордостью рассказывают о своих недавних поездках в Италию, а хорошая беседа бодрит душу.
#
# 59. Реальный текст:
# 	Она найдёт своё отражение в нескольких произведениях писателя, в том числе и его самом последнем и грандиозном романе «Братья Карамазовы».
# Аугметированный текст:
# 	Это отражено во многих произведениях писателя, в том числе в его последнем и величайшем романе «Братья Карамазовы».
#
# 60. Реальный текст:
# 	В 2016 году четыре крупных европейских университета вместе с Университетом Гарварда создали двухгодичную программу для изучения мемов. Однако их программа предусматривает подготовку к получению степени магистра по эволюционной биологии.
# Аугметированный текст:
# 	В 2016 году четыре крупных европейских университета в партнерстве с Гарвардским университетом запустили двухлетнюю программу по изучению мемов. Но их программа готовит вас к получению степени магистра эволюционной биологии.
#
# 61. Реальный текст:
# 	Должна быть создана и правовая основа для оценки вины, когда автомобиль без водителя попадает в аварию.
# Аугметированный текст:
# 	В случае ДТП с оставленным без присмотра автомобилем должна быть создана правовая основа для оценки дефектов.
#
# 62. Реальный текст:
# 	«Я напрягаю две основные мышцы руки: “сгибатель” и “разгибатель”. Когда напрягаю верхнюю мышцу, два электрода “открывают” протез, когда нижнюю — “закрывают”», — объясняет он принцип работы своей бионической руки.
# Аугметированный текст:
# 	«Я напрягаю две основные мышцы руки: сгибатели и разгибатели. Когда я напрягаю верхние мышцы, два электрода «открывают» протез, а нижние — «шапочки» — объясняют, как работает его бионическая рука.
#
# 63. Реальный текст:
# 	Искусство составляет одну из высших сфер деятельности духа. Эта сторона искусства не есть что-то отвлечённое, мечтательное, безразличное; напротив, она заключает в себе многие области, заселённые живыми, конкретными образами. Чудная страна!
# Аугметированный текст:
# 	Искусство представляет собой одну из высших сфер духовной деятельности. Этот аспект искусства не является чем-то абстрактным, мечтательным, неразличимым; Напротив, есть много территорий, населенных яркими и специфическими образами. Удивительная страна!
#
# 64. Реальный текст:
# 	Заигрывание с публикой и зависимость от этого заигрывания неизбежно предопределяют фальшивую оптимистичность. Люди молчат о том, что они одни, что им страшно, что они ничтожны.
# Аугметированный текст:
# 	Азартные игры и зависимость от аудитории неизбежно приводят к ложному оптимизму. Люди говорят о том, как они одиноки, насколько они ужасны, насколько они ничтожны.
#
# 65. Реальный текст:
# 	В конце 1849 года его приговаривают к смертной казни за участие в кружке, где изучали и пропагандировали социализм, высказывали идеи революционного характера.
# Аугметированный текст:
# 	В конце 1849 года его приговорили к смертной казни за вступление в клуб, где он изучал и пропагандировал социализм и выражал революционные идеи.
#
# 66. Реальный текст:
# 	Кроме того, среди мемов существует конкуренция, которая выражается в борьбе за место в человеческой памяти и за внимание, уделяемое мему. Что же может быть мемом?
# Аугметированный текст:
# 	Кроме того, между мемами существует конкуренция, которая проявляется в борьбе за пространство человеческой памяти и внимание к мемам. Каким может быть мем?
#
# 67. Реальный текст:
# 	Поэтому есть надежда на искусственную кожу и другие разработки в области обратной связи», — поясняет он. Есть технологии, которые можно применять уже сейчас, уверен Костя.
# Аугметированный текст:
# 	Так что есть надежда на развитие искусственного интеллекта и обратной связи», — сказал он. Костя уверен в технологиях, которые используются до сих пор.
#
# 68. Реальный текст:
# 	По Докинзу, мемами могут быть мелодии, идеи, крылатые выражения, распространённые представления и так далее. Мемы могут поддерживать друг друга и существовать вместе, в виде единого комплекса — мемплекса.
# Аугметированный текст:
# 	По мнению Докина, мемами могут быть мелодии, идеи, лозунги, популярные идеи и многое другое. Мемы могут поддерживать друг друга и сосуществовать как единое целое.
#
# 69. Реальный текст:
# 	По словам Кости, им не хватает возможности «горячей» замены аккумулятора: чтобы человек мог сходить, например, в поход в горы, не переживая о том, что у него разрядится рука.
# Аугметированный текст:
# 	По словам Кости, поменять «горячую» батарею нет возможности: например, можно отправиться на прогулку в горы, не опасаясь, что в руках сядет батарея.
#
# 70. Реальный текст:
# 	Также возникают проблемы с использованием сенсорных экранов и казусы при оформлении загранпаспорта, когда нужно оставить отпечатки пальцев. «Видели бы вы лицо женщины, которая этим занималась».
# Аугметированный текст:
# 	Также существуют проблемы с использованием сенсорных экранов и выдачей загранпаспортов, требующих снятия отпечатков пальцев. «Вы бы видели лицо женщины, которая это сделала.
#
# 71. Реальный текст:
# 	Свои мысли об этом моменте автор вложит в монолог князя Мышкина в самом начале романа «Идиот». После каторги Достоевский отправляется рядовым солдатом на военную службу — в сибирский город Семипалатинск.
# Аугметированный текст:
# 	Свое мнение об этом моменте автор высказал в монологе князя Мышкина в начале романа «Идиот». Окончив школу, Достоевский отправился на военную службу рядовым солдатом – в сибирский город Семипалатинск.
#
# 72. Реальный текст:
# 	Позавчера подвернул ногу, вчера похоронил бабушку, сегодня собака наклала в гостиной – все идёт в топку дневника собственных будней, адресованного по секрету всему свету.
# Аугметированный текст:
# 	Вчера я прикрыла ноги, вчера похоронила бабушку, сегодня в квартиру пришла собака – все есть в моем ежедневнике, тайно адресованном всему миру.
#
# 73. Реальный текст:
# 	У людей с обычными руками не возникает проблем с тем, чтобы, например, взять какую-то вещь в темноте — огромное количество действий человек совершает на автомате.
# Аугметированный текст:
# 	Например, люди с нормальными руками без проблем подбирают предметы в темноте — многие задачи человек выполняет автоматически.
#
# 74. Реальный текст:
# 	Море уравнивает бедных и богатых, восторженных плебеев с «Одноклассников» и манерных патрициев Facebook. У каждого – персональное море. Все либо у воды, либо только оттуда, либо туда.
# Аугметированный текст:
# 	Море уравнивает бедных и богатых, современных плебеев, «благородную нацию» и доброго патриция. Для каждого – личное море. Все либо в воде, либо просто здесь или там.
#
# 75. Реальный текст:
# 	И нет, оно не зелёное и не светится. 3:17–3:37 Наконец опасность частиц пуль зависит от их пробивной силы.
# Аугметированный текст:
# 	И нет, он не зеленый и это не так. 3:17-3:37 В конечном итоге риск попадания мелкой пыли зависит от ее проникновения.
#
# 76. Реальный текст:
# 	Фирме можно верить — за три года своего существования она сумела не только многократно увеличить свои обороты, но и создать разветвлённую дилерскую сеть. 2. Итак, человек начал свой бизнес.
# Аугметированный текст:
# 	Компании можно доверять – за три года работы ей удалось не только многократно увеличить продажи, но и создать развитую сеть дистрибьюторов. 2. Вот как мужчина основал компанию.
#
# 77. Реальный текст:
# 	Ранее он активно содействовал перемещению своих граждан за рубеж для получения образования, а сейчас, наоборот, активно стимулирует их возвращение.
# Аугметированный текст:
# 	Раньше он поддерживал миграцию своих граждан в Россию для получения образования, а теперь, наоборот, активно поддерживает их возвращение.
#
# 78. Реальный текст:
# 	Я вообще хочу достичь такого уровня, чтобы люди не замечали, что у меня вместо рук протезы», — говорит Костя.
# Аугметированный текст:
# 	В общем, я хочу дойти до того, чтобы люди не замечали, что у меня вместо руки протез», — говорит Кошта.
#
# 79. Реальный текст:
# 	«Я хочу, чтобы меня оценивали как специалиста своей профессии и личность, а не как человека с очень дорогими, похожими на руки Терминатора протезами».
# Аугметированный текст:
# 	«Я хочу, чтобы меня воспринимали как эксперта в своей области и личности, а не как человека с очень дорогим протезом, похожим на протез Терминатора».
#
# 80. Реальный текст:
# 	Это — хорошенько изучить опыт преуспевающих фирм и не стесняться копировать его. А ещё лучше — стать полноправным членом одной из таких сильных деловых команд.
# Аугметированный текст:
# 	Это хорошее изучение опыта перспективных компаний и не бойтесь его копировать. А еще лучше – станьте полноправным членом одной из этих эффективных бизнес-команд.
#
# 81. Реальный текст:
# 	А теперь собирает готовых и высококвалифицированных специалистов почти бесплатно». Что касается России, то сегодня, отмечает эксперт, у нас очень странная госполитика – власти никак не могут определиться.
# Аугметированный текст:
# 	И теперь практически бесплатно собирает готовых и опытных специалистов. Что касается России, то сегодня, как подчеркивает эксперт, у нас совершенно особая государственная политика – власть не может нам ничего навязать.
#
# 82. Реальный текст:
# 	«В гонке за человеческим капиталом, конечно, лидируют США, – уверена эксперт. – Когда они первыми из крупных экономических держав оказались в кризисе, я с интересом изучала антикризисную программу Обамы».
# Аугметированный текст:
# 	"Конечно, США - лидер в конкуренции за человеческий капитал", - уверен эксперт. - Я с интересом изучал антикризисную программу Обамы, когда он стал первой крупной экономикой, попавшей в кризис.
#
# 83. Реальный текст:
# 	Нет смысла заменять слово «инвалид» каким-то другим. Пока об инвалидах не начнут говорить открыто, это слово будет связано с чем-то плохим, чужим и неудачным.
# Аугметированный текст:
# 	Нет смысла заменять слово «недействительный» на что-то другое. Пока мы не говорим открыто о людях с ограниченными возможностями, это слово ассоциируется с чем-то неправильным, странным, неудавшимся.
#
# 84. Реальный текст:
# 	Mapillary использует программное обеспечение для машинного зрения, чтобы анализировать краудсорсинговые изображения и идентифицировать объекты. Лица и номерные знаки автоматически размываются.
# Аугметированный текст:
# 	Mapillary использует программное обеспечение для обработки изображений для анализа краудсорсинговых изображений и идентификации объектов. Лица и регистрационные номера автоматически удаляются.
#
# 85. Реальный текст:
# 	Бедный, так и не выпьешь нормально. Не расслабишься. Заснять, вывесить, ответить комментаторам, смайлики. Море! Все социальные сети – насквозь солоны!
# Аугметированный текст:
# 	Бедняжка, ты обычно пьешь. Не отдыхайте. Запускайте, публикуйте, отвечайте комментаторам, смайликам. Более! Все соцсети - всегда соленые!
#
# 86. Реальный текст:
# 	Сегодня соблазн публичности поражает всё большее число недавно ещё скромных и безвестных. И, разумеется, почти во всех отчётностях, даже если о трагедиях, присутствует оттенок конферанса.
# Аугметированный текст:
# 	Привлекательность рекламы сегодня затрагивает людей, которые до недавнего времени были скромными и неизвестными. И вне всякого сомнения, почти все события, даже трагедии, имеют мыслительную среду.
#
# 87. Реальный текст:
# 	Но если они попадают внутрь организма с пылью, едой или водой, они беспощадно расстреливают клетки в упор, а гамма-радиация пронизывает человека насквозь, но и угодить под неё гораздо сложнее.
# Аугметированный текст:
# 	Однако, попадая в организм с почвой, пищей или водой, они стреляют без разбора по клеткам, и гамма-излучение проникает в человека, но попасть под него гораздо сложнее.
#
# 88. Реальный текст:
# 	«Обычно люди с односторонней ампутацией рук не умеют обращаться с протезом — почти 80 процентов действий можно сделать одной рукой. Мы хотим мотивировать людей использовать новые технические возможности», — отмечает Костя.
# Аугметированный текст:
# 	«Люди с односторонней ампутацией, как правило, не могут пользоваться протезами — около 80 процентов действий можно выполнять одной рукой. Мы хотим побудить людей использовать новые технические возможности», — говорит Костя.
#
# 89. Реальный текст:
# 	Считается, что вредные дозы начинаются со ста миллизивертов, а смертельные — с пяти тысяч. Теперь вы понимаете, что при слове «радиация» не стоит каждый раз впадать в панику.
# Аугметированный текст:
# 	Считается, что вредная доза начинается со ста миллизивертов и смертельная с пяти тысяч миллизивертов. Теперь вы понимаете, что слово «радиация» не должно каждый раз вызывать панику.
#
# 90. Реальный текст:
# 	Костя называет себя киборгом с оговоркой, что в киборге происходит полное слияние технологий и человеческого организма, но пока это не совсем так.
# Аугметированный текст:
# 	Боуна называют киборгом, киборгом, представляющим собой идеальное сочетание технологий и человеческого тела, но это не так.
#
# 91. Реальный текст:
# 	Эта частота появлений (в телеке, на сайте) навязывает персонажа, делает его всё узнаваемее и всё легковеснее, истончая, как кусок мыла.
# Аугметированный текст:
# 	Эта частота (на ТВ, в Интернете) связывает персонажа, делает его более узнаваемым и легким, делает нежным, как мыльный поцелуй.
#
# 92. Реальный текст:
# 	Они справедливо хотят поднять конкурентоспособность российских университетов, требуют от них прогресса в мировых рейтингах. Но как достигается этот прогресс? Например, числом студентов или аспирантов, учащихся в ведущих вузах мира.
# Аугметированный текст:
# 	Они справедливо хотят повысить конкурентоспособность российских вузов и требуют от них повышения в мировых рейтингах. Но как добиться этого успеха? Например, количество студентов или аспирантов, обучающихся в ведущих университетах мира.
#
# 93. Реальный текст:
# 	00:01:38 Условия уже известны — проехать 50 километров меньше чем за 3 часа. Лучшая компания получит 175 миллионов рублей на развитие своей модели.
# Аугметированный текст:
# 	00:01:38 Условия теперь известны - преодолеть 50 километров менее чем за 3 часа. Лучшая компания получит 175 миллионов рублей на разработку своей модели.
#
# 94. Реальный текст:
# 	И так каждый день до 5 марта. 00:01:26 «Те, кто преодолеет больше 50 процентов заданий, будут допущены к основному этапу конкурса, и в декабре 19-го года пройдут уже комплексные испытания».
# Аугметированный текст:
# 	Ежедневно до 5 марта. 00:01:26 «Те, кто выполнил более 50 процентов заданий, до 19 декабря выйдут в основной этап конкурса и пройдут расширенное тестирование».
#
# 95. Реальный текст:
# 	Он также мечтает о том, чтобы в протез можно было встроить гаджет типа смартфона — и не искать его, долго доставая из карманов.
# Аугметированный текст:
# 	Еще он мечтает, чтобы такое устройство, как смартфон, могло стать протезом – и чтобы он мог долго доставать его из кармана, не ища.
#
# 96. Реальный текст:
# 	В мире обострилась конкуренция за таланты: их переманивают высокими зарплатами и головокружительными перспективами. Во Всемирной организации интеллектуальной собственности (ВОИС) обозначили масштаб явления.
# Аугметированный текст:
# 	Во всем мире обострилась конкуренция за таланты: они конкурируют с высокими зарплатами и головокружительными перспективами. Всемирная организация интеллектуальной собственности (WIOIS) определила масштабы этого явления.
#
# 97. Реальный текст:
# 	На первых порах производство и продажа жалюзи по размерам, указанным заказчиком, вообще может быть чисто семейным бизнесом. Немаловажный фактор — и цена.
# Аугметированный текст:
# 	На начальном этапе производство и продажа штор по размерам заказчика в большинстве случаев может быть чисто семейным бизнесом. Важным фактором является цена.
#
# 98. Реальный текст:
# 	Авто без водителя — не фантастика, а обозримое будущее. По прогнозам экспертов, первыми полноценными беспилотниками станут микроавтобусы. В рейсы выйдут уже к 2030 году.
# Аугметированный текст:
# 	Беспилотные автомобили – не фантастика, а сомнительное будущее. По мнению экспертов, фургоны — первые полностью автономные транспортные средства. Эти полеты будут прекращены к 2030 году.
#
# 99. Реальный текст:
# 	Подобно гену, мемы способны к самовоспроизведению (или репликации) и распространяются от одного человека к другому.
# Аугметированный текст:
# 	Как и гены, мемы могут воспроизводиться (или размножаться) и передаваться от человека к человеку.
#
# 100. Реальный текст:
# 	Это в семь раз меньше обычной томографии и в пятьдесят раз меньше допустимой ежегодной дозы для работников на опасном производстве.
# Аугметированный текст:
# 	Это в семь раз ниже нормальной томографической нормы и в пятьдесят раз ниже годовой допустимой дозы для работников опасных производств.
#
# 101. Реальный текст:
# 	Пока с самого детства здоровым детям не будут говорить о том, что мы существуем и что мы ничуть не хуже остальных, замены слов не помогут».
# Аугметированный текст:
# 	Если здоровым детям с раннего возраста не внушать, что мы такие и есть не хуже других, то изменение слов не поможет.
#
# 102. Реальный текст:
# 	2:14–2:34 Когда много таких микропуль попадает в живой организм, они разрушают его молекулы. Некоторые клетки погибают, другие выживают, но с повреждённым кодом ДНК.
# Аугметированный текст:
# 	2:14-2:34 Когда множество таких микроимпульсов достигают живого организма, они разрушают его молекулы. Некоторые клетки умирают, другие выживают, но код ДНК нарушается.
#
# 103. Реальный текст:
# 	Тогда обратите внимание на некоторые преуспевающие в этой области фирмы. В чём причина такого успеха?
# Аугметированный текст:
# 	Так что обратите внимание на некоторые успешные компании в этой области. В чем причина такого успеха?
#
# 104. Реальный текст:
# 	Ведь вы и сами знаете, что и паника, и безразличие одинаково бесполезны в любой жизненной ситуации.
# Аугметированный текст:
# 	Вы сами знаете, что паника и беспечность одинаково бесполезны во всех ситуациях.
#
# 105. Реальный текст:
# 	Обычным делом на дорогах они станут только к 2030 году, а полностью вытеснят с дорог обычные машины только к 2035. Что не так с онлайн-картами?
# Аугметированный текст:
# 	К 2030 году они будут повсеместно на дорогах, а к 2035 году полностью заменят обычные автомобили. Что не так с сетевыми картами?
#
# 106. Реальный текст:
# 	Так вот, вопреки ожиданиям, расходы на образование тогда не были сокращены. Стало ясно: они собирались сохранить за собой статус интеллектуального лидера». Интересен и пример Китая.
# Аугметированный текст:
# 	В результате расходы на образование не снизились по сравнению с ожиданиями. Было ясно: они объединились, чтобы утвердить свой статус интеллектуальных лидеров. Китайский пример интересен.
#
# 107. Реальный текст:
# 	Судя по рассказам менеджеров «Промы», расширять круг деловых партнёров этой фирме помогает то, что активно сотрудничать с ней могут даже начинающие предприниматели.
# Аугметированный текст:
# 	По рассказам менеджеров «Проми», эта компания помогает расширить круг деловых партнеров, так как с ней могут активно сотрудничать начинающие предприниматели.
#
# 108. Реальный текст:
# 	Так же радиация — это частица, которая летит на огромной скорости. Сама частица может быть почти любой: от атомного ядра до электрона или фотона.
# Аугметированный текст:
# 	Также радиация – частица, летящая с большой скоростью. Сама частица может быть практически чем угодно: от атомного ядра до электрона или фотона.
#
# 109. Реальный текст:
# 	00:00:46 Радары ближнего действия по бокам для перестроения, 8 камер на крыше для дополнительного контроля, 16 парктроников. Вся электроника, которая запускает работу, вот в этой коробке в салоне.
# Аугметированный текст:
# 	00:00:46 Закрытые боковые радары для реорганизации, 8 камер на крыше для дополнительного ориентирования, 16 парктроников. Вся электроника, обеспечивающая его работу, находится в коробке в коридоре.
#
# 110. Реальный текст:
# 	И мемы с животными — это образы, вирусы, которые успокаивают нас, усыпляют нашу бдительность и примиряют с окружающим нас миром технологий.
# Аугметированный текст:
# 	А мемы о животных — это изображения, вирусы, которые нас успокаивают, призывают быть настороже и имитируют технологический мир вокруг нас.
#
# 111. Реальный текст:
# 	Но это не мы, а техно-мемы заполоняют мир благодаря машинерии, которая копирует, рекомбинирует, хранит и распространяет их. Это они стремительно эволюционируют, в то время как человеческие тела остаются прежними».
# Аугметированный текст:
# 	А мы нет, технологи населяют мир благодаря машине, которая их копирует, объединяет, хранит и распространяет. Они быстро развивались, тогда как человеческое тело оставалось примитивным.
#
# 112. Реальный текст:
# 	Если исповедь предполагает тайну, то антиисповедь стремится к максимальному числу фолловеров. Любовь, дети, близкие – личное измерение человека препарируется им на публике со спешкой, доходящей до оголтелости.
# Аугметированный текст:
# 	Если история требует истины, антиистория стремится к как можно большему числу последователей. Любовь, дети, близкие люди – личностные измерения человека спешно готовятся для общества до самой смерти.
#
# 113. Реальный текст:
# 	При этом определение того, что является «разумным», выступает не столько технической, сколько нормативной задачей. Каждый раз, когда автомобиль без водителя принимает решение, он должен найти компромисс между безопасностью и полезностью.
# Аугметированный текст:
# 	Определение того, что является «справедливым», является не столько техническим, сколько нормативным вопросом. Когда беспилотный автомобиль принимает решение, он должен найти компромисс между безопасностью и полезностью.
#
# 114. Реальный текст:
# 	От одного банана — в два раза больше (0,1), а вот такую дозу каждый из нас получает ежедневно (10). Рентген груди — двухдневная фоновая доза (20).
# Аугметированный текст:
# 	От банана – в два раза больше (0,1) и именно такую ​​дозу получает каждый из нас в день (10). Рентгенограмма грудной клетки – двухдневная фонология (20).
#
# 115. Реальный текст:
# 	00:00:24 А сегодня испытания. 13 участников. Жюри определит, насколько автомобили готовы к поездкам зимой. — Как она видит людей, как реагирует на светофоры, что в ней? — Радар дальнего действия.
# Аугметированный текст:
# 	00:00:24 Сегодняшний тест. 13 участников. Жюри определит, насколько машины подготовлены к зимней эксплуатации. «Как он видит людей, как он реагирует на свет, который находится внутри него?» - Радар дальнего действия.
#
# 116. Реальный текст:
# 	«Прома» способна предложить дилерам вполне божеские цены на комплектующие, а при длительном сотрудничестве практикует систему скидок и льгот. Предпринимателями хотят быть если не все, то очень и очень многие.
# Аугметированный текст:
# 	«Прома» способна предложить продавцам относительно хорошую цену на комплектующие, а также систему скидок и скидок при долгосрочном сотрудничестве. Многие, если не все, хотят стать предпринимателями.
#
# 117. Реальный текст:
# 	Tesla — не единственный игрок на рынке: большинство крупных автопроизводителей — Ford, Honda, Toyota, Nissan, Volvo, BMW, Hyundai — планируют представить полностью беспилотные автомобили в ближайшие 2–4 года.
# Аугметированный текст:
# 	Tesla — не единственный игрок на рынке: большинство крупных производителей автомобилей — Ford, Honda, Toyota, Nissan, Volvo, BMW, Hyundai — планируют представить беспилотные автомобили в ближайшие два-четыре года.
#
# 118. Реальный текст:
# 	Понятно, что среди крупнейших стран – поставщиков высококлассной рабочей силы на международный рынок – Китай и Индия. Но вот ещё один парадокс – у них показатели «утечки мозгов» невелики.
# Аугметированный текст:
# 	Понятно, что Китай и Индия являются крупнейшими поставщиками качественной рабочей силы на международном рынке. Но есть парадокс: есть некоторые индикаторы утечки мозгов.
#
# 119. Реальный текст:
# 	Он велик, этот подвиг: жечь себя живьём на виртуальных кострах, вопреки всему – нервам, удовольствиям, отдыху и, наконец, делу.
# Аугметированный текст:
# 	Это прекрасное движение: несмотря ни на что – нервы, удовольствие, отдых и, наконец, работу – позвольте себе побыть на виртуальном пляже.
