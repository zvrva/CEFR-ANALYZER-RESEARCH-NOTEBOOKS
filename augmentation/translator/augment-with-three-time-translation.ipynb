# %%
import requests
import pandas as pd
import time
import re
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
import asyncio
import pandas as pd
from googletrans import Translator

# %%
try:
    df = pd.read_csv('ru_cefr_short.csv')
    print("✅ Файл найден:")
except:
    print("❌ Файл не найден, используем тестовые данные:")
    test_data = {
        'fragment': [
            "Весной, летом и осенью почти каждую субботу он играет в футбол. У них в школе есть футбольная команда. А зимой он играет в хоккей. Ещё мы любим театр.",
            "Вчера я весь вечер повторял грамматику, учил слова. В контрольной работе я сделал 3 ошибки. Питер и Кен написали всё без ошибок. Преподаватель сказал, что они делают большие успехи.",
            "В такой ситуации особенно сложно работающим студентам, которые должны находить время и для учёбы, и для работы. Это нередко вызывает стресс.",
            "Как редкое животное они стоили очень дорого и являлись предметом роскоши. Археологи нашли останки этих животных в развалинах домов богатых людей четвёртого века нашей эры.",
            "Он увлёкся энтомологией ещё мальчиком и в детстве познакомился с основными учёными трудами в этой области.",
            "Так же радиация — это частица, которая летит на огромной скорости. Сама частица может быть почти любой: от атомного ядра до электрона или фотона."
        ],
        'textbook-assigned cefr level': [1, 2, 3, 4, 5, 6]
    }
    df = pd.DataFrame(test_data)

df
# Out:
# ✅ Файл найден:
#                                                fragment  \
# 0     Весной, летом и осенью почти каждую субботу он...
# 1     Все говорят, что мама хорошая хозяйка. А ещё н...
# 2     На каждой двери красные плакаты и красные фона...
# 3     Я считаю деньги, в час обедаю в кафе, а потом ...
# 4     Магазин «Чёрный квадрат» открывается в 9 часов...
# ...                                                 ...
# 7317  Утечка мозгов стала ключевым трендом междунаро...
# 7318  По оценкам менеджеров «Промы», такая ситуация ...
# 7319  Но это не мы, а техно-мемы заполоняют мир благ...
# 7320  Mapillary использует программное обеспечение д...
# 7321  Новое роботакси, разрабатываемое Маском, сможе...
#
#       textbook-assigned cefr level
# 0                                1
# 1                                1
# 2                                1
# 3                                1
# 4                                1
# ...                            ...
# 7317                             6
# 7318                             6
# 7319                             6
# 7320                             6
# 7321                             6
#
# [7322 rows x 2 columns]

# %%
train_texts, val_texts, train_labels, val_labels = train_test_split(
    df['fragment'].values,
    df['textbook-assigned cefr level'].values,
    test_size=0.2,
    random_state=42,
    stratify=df['textbook-assigned cefr level']
)

len(train_texts)
# Out:
# 5857

# %%
texts_to_augment = []

for i in range(len(train_labels)):
  if train_labels[i] == 6:
    texts_to_augment.append(train_texts[i])


len(texts_to_augment)
# Out:
# 120

# %%
async def main():
    print(f"Аугментируем {len(texts_to_augment)} текстов...")
    df_pred = pd.DataFrame(columns=['text', 'augmented-text'])

    translator = Translator()

    translated_to = await translator.translate(texts_to_augment, src='ru', dest='ko')
    print("Переведено на корейский")
    
    translated_to = await translator.translate([trans.text for trans in translated_to], src='ko', dest='it')
    print("Переведено на итальянский")
    
    translated_to = await translator.translate([trans.text for trans in translated_to], src='it', dest='uz')
    print("Переведено на узбекский")
    
    translated_to = await translator.translate([trans.text for trans in translated_to], src='uz', dest='ru')
    print("Переведено обратно на русский")

    for n in range(len(texts_to_augment)):
        print(f"\n{n}. Реальный текст:\n\t{texts_to_augment[n]}")
        print(f"Аугметированный текст:\n\t{translated_to[n].text}")

        new_row = pd.DataFrame({
            'text': [texts_to_augment[n]],
            'augmented-text': [translated_to[n].text]
        })
        df_pred = pd.concat([df_pred, new_row], ignore_index=True)

    output_filename = "c2_augmented_three_times_translated.csv"
    df_pred.to_csv(output_filename, index=False, encoding='utf-8-sig')


    return df_pred

df_pred = await main()
# Out:
# Аугментируем 120 текстов...
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[10], line 35
#      30     df_pred.to_csv(output_filename, index=False, encoding='utf-8-sig')
#      33     return df_pred
# ---> 35 df_pred = await main()
#
# Cell In[10], line 7, in main()
#       3 df_pred = pd.DataFrame(columns=['text', 'augmented-text'])
#       5 translator = Translator()
# ----> 7 translated_to = await translator.translate(texts_to_augment, src='ru', dest='zh-cn')
#       8 print("Переведено на китайский")
#      10 translated_to = await translator.translate([trans.text for trans in translated_to], src='zh-cn', dest='it')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\googletrans\client.py:282, in Translator.translate(self, text, dest, src, **kwargs)
#     279             return await self.translate(item, dest=dest, src=src, **kwargs)
#     281     tasks = [translate_with_semaphore(item) for item in text]
# --> 282     result = await asyncio.gather(*tasks)
#     283     return result
#     285 origin = text
#
# File ~\AppData\Roaming\Python\Python312\site-packages\googletrans\client.py:278, in Translator.translate.<locals>.translate_with_semaphore(item)
#     277 async def translate_with_semaphore(item):
# --> 278     async with semaphore:
#     279         return await self.translate(item, dest=dest, src=src, **kwargs)
#
# File c:\Program Files\Python312\Lib\asyncio\locks.py:14, in _ContextManagerMixin.__aenter__(self)
#      13 async def __aenter__(self):
# ---> 14     await self.acquire()
#      15     # We have no use for the "as ..."  clause in the with
#      16     # statement for locks.
#      17     return None
#
# File c:\Program Files\Python312\Lib\asyncio\locks.py:386, in Semaphore.acquire(self)
#     384 try:
#     385     try:
# --> 386         await fut
#     387     finally:
#     388         self._waiters.remove(fut)
#
# CancelledError:
