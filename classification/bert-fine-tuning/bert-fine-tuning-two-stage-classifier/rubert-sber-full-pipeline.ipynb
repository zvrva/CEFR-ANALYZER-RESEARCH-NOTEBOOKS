# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, mean_absolute_error
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from torch.utils.data import Dataset
import os
import time
from datetime import timedelta
import sys
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Используемое устройство: {device}")
# Out:
# Используемое устройство: cuda

# %%
class CEFRDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=512):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = str(self.texts[idx])
        label = int(self.labels[idx])

        encoding = self.tokenizer(
            text,
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors='pt'
        )

        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# %%
df = pd.read_csv('ru_cefr_short.csv')
df['label'] = df['textbook-assigned cefr level'].astype(int)
df
# Out:
#                                                fragment  \
# 0     Весной, летом и осенью почти каждую субботу он...
# 1     Все говорят, что мама хорошая хозяйка. А ещё н...
# 2     На каждой двери красные плакаты и красные фона...
# 3     Я считаю деньги, в час обедаю в кафе, а потом ...
# 4     Магазин «Чёрный квадрат» открывается в 9 часов...
# ...                                                 ...
# 7317  Утечка мозгов стала ключевым трендом междунаро...
# 7318  По оценкам менеджеров «Промы», такая ситуация ...
# 7319  Но это не мы, а техно-мемы заполоняют мир благ...
# 7320  Mapillary использует программное обеспечение д...
# 7321  Новое роботакси, разрабатываемое Маском, сможе...
#
#       textbook-assigned cefr level  label
# 0                                1      1
# 1                                1      1
# 2                                1      1
# 3                                1      1
# 4                                1      1
# ...                            ...    ...
# 7317                             6      6
# 7318                             6      6
# 7319                             6      6
# 7320                             6      6
# 7321                             6      6
#
# [7322 rows x 3 columns]

# %%
train_texts, val_texts, train_labels, val_labels = train_test_split(
    df['fragment'].values,
    df['label'].values,
    test_size=0.2,
    random_state=42,
    stratify=df['label']
)

train_or_test = []
for i in range(len(df)):
    if df['fragment'][i] in val_texts:
        train_or_test.append(0)
    else:
        train_or_test.append(1)

df['train_or_test'] = train_or_test
df
# Out:
#                                                fragment  \
# 0     Весной, летом и осенью почти каждую субботу он...
# 1     Все говорят, что мама хорошая хозяйка. А ещё н...
# 2     На каждой двери красные плакаты и красные фона...
# 3     Я считаю деньги, в час обедаю в кафе, а потом ...
# 4     Магазин «Чёрный квадрат» открывается в 9 часов...
# ...                                                 ...
# 7317  Утечка мозгов стала ключевым трендом междунаро...
# 7318  По оценкам менеджеров «Промы», такая ситуация ...
# 7319  Но это не мы, а техно-мемы заполоняют мир благ...
# 7320  Mapillary использует программное обеспечение д...
# 7321  Новое роботакси, разрабатываемое Маском, сможе...
#
#       textbook-assigned cefr level  label  train_or_test
# 0                                1      1              1
# 1                                1      1              0
# 2                                1      1              1
# 3                                1      1              1
# 4                                1      1              0
# ...                            ...    ...            ...
# 7317                             6      6              1
# 7318                             6      6              1
# 7319                             6      6              1
# 7320                             6      6              1
# 7321                             6      6              0
#
# [7322 rows x 4 columns]

# %%
model_name = 'sberbank-ai/ruBert-large'
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
training_args = TrainingArguments(
    num_train_epochs=3,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    warmup_steps=100,
    weight_decay=0.01,
    logging_steps=100,
    eval_strategy='epoch',
    save_strategy='epoch',
    load_best_model_at_end=True,
    metric_for_best_model='eval_loss',
    greater_is_better=False,
    learning_rate=2e-5
)

# %%
def evaluate_model(model, val_dataset, device):
    model.eval()
    predictions = []
    true_labels = []

    with torch.no_grad():
        for i in range(len(val_dataset)):
            batch = val_dataset[i]
            
            inputs = {
                'input_ids': batch['input_ids'].unsqueeze(0).to(device),
                'attention_mask': batch['attention_mask'].unsqueeze(0).to(device)
            }
            
            outputs = model(**inputs)
            pred = torch.argmax(outputs.logits, dim=1).item()
            predictions.append(pred + 1)  
            true_labels.append(batch['labels'].item() + 1)  

    return true_labels, predictions

# %% [markdown]
# # A/B/C

# %%
df_level1 = df.copy()
df_level1['label'] = df_level1['label'].map({1: 0, 2: 0, 3:1, 4:1, 5:2, 6:2})
df_level1
# Out:
#                                                fragment  \
# 0     Весной, летом и осенью почти каждую субботу он...
# 1     Все говорят, что мама хорошая хозяйка. А ещё н...
# 2     На каждой двери красные плакаты и красные фона...
# 3     Я считаю деньги, в час обедаю в кафе, а потом ...
# 4     Магазин «Чёрный квадрат» открывается в 9 часов...
# ...                                                 ...
# 7317  Утечка мозгов стала ключевым трендом междунаро...
# 7318  По оценкам менеджеров «Промы», такая ситуация ...
# 7319  Но это не мы, а техно-мемы заполоняют мир благ...
# 7320  Mapillary использует программное обеспечение д...
# 7321  Новое роботакси, разрабатываемое Маском, сможе...
#
#       textbook-assigned cefr level  label  train_or_test
# 0                                1      0              1
# 1                                1      0              0
# 2                                1      0              1
# 3                                1      0              1
# 4                                1      0              0
# ...                            ...    ...            ...
# 7317                             6      2              1
# 7318                             6      2              1
# 7319                             6      2              1
# 7320                             6      2              1
# 7321                             6      2              0
#
# [7322 rows x 4 columns]

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=3,
    id2label={0: 'A', 1: 'B', 2: 'C'},
    label2id={'A': 0, 'B': 1, 'C': 2}
)

model = model.to(device)
print(f"Модель инициализирована")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at sberbank-ai/ruBert-large and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Модель инициализирована

# %%
train_texts, val_texts, train_labels, val_labels = [],[],[],[]
for i in range(len(df_level1)):
    if df_level1['train_or_test'][i] == 1:
        train_texts.append(df_level1['fragment'][i])
        train_labels.append(df_level1['label'][i])
    else:
        val_texts.append(df_level1['fragment'][i])
        val_labels.append(df_level1['label'][i])

train_dataset = CEFRDataset(train_texts, train_labels, tokenizer)
val_dataset = CEFRDataset(val_texts, val_labels, tokenizer)


print(f"Обучающая выборка: {len(train_texts)}")
print(f"Валидационная выборка: {len(val_texts)}")
# Out:
# Обучающая выборка: 5833
# Валидационная выборка: 1489

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

# %%
train_start_time = time.time()
trainer.train()
train_time = time.time() - train_start_time
print(f"Обучение завершено за {train_time:.2f} секунд ({timedelta(seconds=int(train_time))})")
# Out:
#     <div>
#
#       <progress value='2190' max='2190' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2190/2190 09:45, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.586500</td>
#       <td>0.621558</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.288000</td>
#       <td>0.908370</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.066700</td>
#       <td>1.080411</td>
#     </tr>
#   </tbody>
# </table><p>
# Обучение завершено за 586.42 секунд (0:09:46)

# %%
true_labels, predictions = evaluate_model(model, val_dataset, device)

accuracy = accuracy_score(true_labels, predictions)
f1_micro = f1_score(true_labels, predictions, average="micro")
f1_macro = f1_score(true_labels, predictions, average="macro")
f1_weighted = f1_score(true_labels, predictions, average="weighted")
mae = mean_absolute_error(true_labels, predictions)

print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Micro: {f1_micro:.4f}")
print(f"F1 Macro: {f1_macro:.4f}")
print(f"F1 Weighted: {f1_weighted:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# Accuracy: 0.7515
# F1 Micro: 0.7515
# F1 Macro: 0.7296
# F1 Weighted: 0.7508
# MAE: 0.2498

# %%
cm = confusion_matrix(true_labels, predictions)

fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(cm, cmap='Blues')

ax.set_xticks(range(3))
ax.set_yticks(range(3))
ax.set_xticklabels(['A', 'B', 'C'])
ax.set_yticklabels(['A', 'B', 'C'])

for i in range(3):
    for j in range(3):
        ax.text(j, i, cm[i, j], ha='center', va='center')

plt.xlabel('Предсказанные')
plt.ylabel('Истинные')
plt.title('Матрица ошибок')
plt.colorbar(im)
plt.show()

# %%
print(f"{accuracy:.4f}\n{f1_micro:.4f}\n{f1_macro:.4f}\n{f1_weighted:.4f}\n{mae:.4f}\n{train_time:.2f}")
# Out:
# 0.7515
# 0.7515
# 0.7296
# 0.7508
# 0.2498
# 586.42

# %% [markdown]
# # A1/A2

# %%
df_A = df.copy()
df_A = df_A[df_A['label'] <=2]
df_A['label'] = df_A['label'].map({1: 0, 2: 1})
df_A
# Out:
#                                                fragment  \
# 0     Весной, летом и осенью почти каждую субботу он...
# 1     Все говорят, что мама хорошая хозяйка. А ещё н...
# 2     На каждой двери красные плакаты и красные фона...
# 3     Я считаю деньги, в час обедаю в кафе, а потом ...
# 4     Магазин «Чёрный квадрат» открывается в 9 часов...
# ...                                                 ...
# 1894  В самом деле, мне очень жалко, что у людей ест...
# 1895  Я думаю, что счастлива баллов на 8. Если бы у ...
# 1896  У́тром пьём крепкий кофе или чай, потому что м...
# 1897  Я был там с девушкой. Мы спали в лесу в палатк...
# 1898  Через 4 года он должен будет уйти на пенсию. Я...
#
#       textbook-assigned cefr level  label  train_or_test
# 0                                1      0              1
# 1                                1      0              0
# 2                                1      0              1
# 3                                1      0              1
# 4                                1      0              0
# ...                            ...    ...            ...
# 1894                             2      1              1
# 1895                             2      1              1
# 1896                             2      1              0
# 1897                             2      1              1
# 1898                             2      1              0
#
# [1899 rows x 4 columns]

# %%
model_A = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=2,
    id2label={0: 'A1', 1: 'A2'},
    label2id={'A1': 0, 'A2': 1}
)

model_A = model_A.to(device)
print(f"Модель инициализирована")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at sberbank-ai/ruBert-large and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Модель инициализирована

# %%
train_texts, val_texts, train_labels, val_labels = [],[],[],[]
for i in range(len(df_A)):
    if df_A['train_or_test'][i] == 1:
        train_texts.append(df_A['fragment'][i])
        train_labels.append(df_A['label'][i])
        
    else:
        val_texts.append(df_A['fragment'][i])
        val_labels.append(df_A['label'][i])

train_dataset = CEFRDataset(train_texts, train_labels, tokenizer)
val_dataset = CEFRDataset(val_texts, val_labels, tokenizer)


print(f"Обучающая выборка: {len(train_texts)}")
print(f"Валидационная выборка: {len(val_texts)}")
# Out:
# Обучающая выборка: 1510
# Валидационная выборка: 389

# %%
trainer = Trainer(
    model=model_A,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

# %%
train_start_time = time.time()
trainer.train()
train_time = time.time() - train_start_time
print(f"Обучение завершено за {train_time:.2f} секунд ({timedelta(seconds=int(train_time))})")
# Out:
#     <div>
#
#       <progress value='567' max='567' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [567/567 02:41, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.654800</td>
#       <td>0.669875</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.313200</td>
#       <td>0.389984</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.117400</td>
#       <td>0.583851</td>
#     </tr>
#   </tbody>
# </table><p>
# Обучение завершено за 161.53 секунд (0:02:41)

# %%
true_labels, predictions = evaluate_model(model_A, val_dataset, device)

accuracy = accuracy_score(true_labels, predictions)
f1_micro = f1_score(true_labels, predictions, average="micro")
f1_macro = f1_score(true_labels, predictions, average="macro")
f1_weighted = f1_score(true_labels, predictions, average="weighted")
mae = mean_absolute_error(true_labels, predictions)

print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Micro: {f1_micro:.4f}")
print(f"F1 Macro: {f1_macro:.4f}")
print(f"F1 Weighted: {f1_weighted:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# Accuracy: 0.8432
# F1 Micro: 0.8432
# F1 Macro: 0.8373
# F1 Weighted: 0.8439
# MAE: 0.1568

# %%
cm = confusion_matrix(true_labels, predictions)

fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(cm, cmap='Blues')

ax.set_xticks(range(2))
ax.set_yticks(range(2))
ax.set_xticklabels(['A1', 'A2'])
ax.set_yticklabels(['A1', 'A2'])

for i in range(2):
    for j in range(2):
        ax.text(j, i, cm[i, j], ha='center', va='center')

plt.xlabel('Предсказанные')
plt.ylabel('Истинные')
plt.title('Матрица ошибок')
plt.colorbar(im)
plt.show()

# %%
print(f"{accuracy:.4f}\n{f1_micro:.4f}\n{f1_macro:.4f}\n{f1_weighted:.4f}\n{mae:.4f}\n{train_time:.2f}")
# Out:
# 0.8432
# 0.8432
# 0.8373
# 0.8439
# 0.1568
# 161.53

# %% [markdown]
# # B1/B2

# %%
df_B = df.copy()
df_B = df_B[(df_B['label'] <= 4) & (df_B['label'] >= 3)]
df_B['label'] = df_B['label'].map({3: 0, 4: 1})
df_B = df_B.reset_index()
df_B
# Out:
#       index                                           fragment  \
# 0      1899  В такой ситуации особенно сложно работающим ст...
# 1      1900  В те времена люди, которые работали на заводах...
# 2      1901  Сначала я изучала русский язык, затем поступил...
# 3      1902  В наше время люди ездят на автомобилях и поезд...
# 4      1903  Журналисты решили добиться своей цели и положи...
# ...     ...                                                ...
# 4086   5985  Старшее поколение любило играть в карты, молод...
# 4087   5986  Одним из самых ярких представителей этой эпохи...
# 4088   5987  Я не только за маузер хватаюсь, но и тру нос д...
# 4089   5988  — Мне трудно сказать, красивый ли это город. И...
# 4090   5989  Мастерское использование цвета позволяет худож...
#
#       textbook-assigned cefr level  label  train_or_test
# 0                                3      0              1
# 1                                3      0              0
# 2                                3      0              1
# 3                                3      0              1
# 4                                3      0              1
# ...                            ...    ...            ...
# 4086                             4      1              1
# 4087                             4      1              1
# 4088                             4      1              1
# 4089                             4      1              1
# 4090                             4      1              1
#
# [4091 rows x 5 columns]

# %%
len(df_B[df_B['label']==0]), len(df_B[df_B['label']==1])
# Out:
# (2375, 1716)

# %%
model_B = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=2,
    id2label={0: 'B1', 1: 'B2'},
    label2id={'B1': 0, 'B2': 1}
)

model_B = model_B.to(device)
print(f"Модель инициализирована")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at sberbank-ai/ruBert-large and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Модель инициализирована

# %%
train_texts, val_texts, train_labels, val_labels = [],[],[],[]
for i in range(len(df_B)):
    if df_B['train_or_test'][i] == 1:
        train_texts.append(df_B['fragment'][i])
        train_labels.append(df_B['label'][i])
        
    else:
        val_texts.append(df_B['fragment'][i])
        val_labels.append(df_B['label'][i])

train_dataset = CEFRDataset(train_texts, train_labels, tokenizer)
val_dataset = CEFRDataset(val_texts, val_labels, tokenizer)


print(f"Обучающая выборка: {len(train_texts)}")
print(f"Валидационная выборка: {len(val_texts)}")
# Out:
# Обучающая выборка: 3266
# Валидационная выборка: 825

# %%
trainer = Trainer(
    model=model_B,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

# %%
train_start_time = time.time()
trainer.train()
train_time = time.time() - train_start_time
print(f"Обучение завершено за {train_time:.2f} секунд ({timedelta(seconds=int(train_time))})")
# Out:
#     <div>
#
#       <progress value='1227' max='1227' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1227/1227 05:33, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.489600</td>
#       <td>0.439579</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.272200</td>
#       <td>0.646598</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.060800</td>
#       <td>0.852361</td>
#     </tr>
#   </tbody>
# </table><p>
# Обучение завершено за 333.84 секунд (0:05:33)

# %%
true_labels, predictions = evaluate_model(model_B, val_dataset, device)

accuracy = accuracy_score(true_labels, predictions)
f1_micro = f1_score(true_labels, predictions, average="micro")
f1_macro = f1_score(true_labels, predictions, average="macro")
f1_weighted = f1_score(true_labels, predictions, average="weighted")
mae = mean_absolute_error(true_labels, predictions)

print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Micro: {f1_micro:.4f}")
print(f"F1 Macro: {f1_macro:.4f}")
print(f"F1 Weighted: {f1_weighted:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# Accuracy: 0.7927
# F1 Micro: 0.7927
# F1 Macro: 0.7876
# F1 Weighted: 0.7929
# MAE: 0.2073

# %%
cm = confusion_matrix(true_labels, predictions)

fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(cm, cmap='Blues')

ax.set_xticks(range(2))
ax.set_yticks(range(2))
ax.set_xticklabels(['B1', 'B2'])
ax.set_yticklabels(['B1', 'B2'])

for i in range(2):
    for j in range(2):
        ax.text(j, i, cm[i, j], ha='center', va='center')

plt.xlabel('Предсказанные')
plt.ylabel('Истинные')
plt.title('Матрица ошибок')
plt.colorbar(im)
plt.show()

# %%
print(f"{accuracy:.4f}\n{f1_micro:.4f}\n{f1_macro:.4f}\n{f1_weighted:.4f}\n{mae:.4f}\n{train_time:.2f}")
# Out:
# 0.7927
# 0.7927
# 0.7876
# 0.7929
# 0.2073
# 333.84

# %% [markdown]
# # C1/C2

# %%
df_C = df.copy()
df_C = df_C[df_C['label'] >= 5]
df_C['label'] = df_C['label'].map({5: 0, 6: 1})
df_C = df_C.reset_index()
df_C
# Out:
#       index                                           fragment  \
# 0      5990  Он увлёкся энтомологией ещё мальчиком и в детс...
# 1      5991  Оказывается, доля этих людей в стране с 2003 г...
# 2      5992  Над заходом нависал балкон с белой же крашеной...
# 3      5993  км, австралийской пустыне. Кстати, не по этой ...
# 4      5994  Кому-то не нравится постоянный шум в плацкарте...
# ...     ...                                                ...
# 1327   7317  Утечка мозгов стала ключевым трендом междунаро...
# 1328   7318  По оценкам менеджеров «Промы», такая ситуация ...
# 1329   7319  Но это не мы, а техно-мемы заполоняют мир благ...
# 1330   7320  Mapillary использует программное обеспечение д...
# 1331   7321  Новое роботакси, разрабатываемое Маском, сможе...
#
#       textbook-assigned cefr level  label  train_or_test
# 0                                5      0              0
# 1                                5      0              1
# 2                                5      0              1
# 3                                5      0              1
# 4                                5      0              1
# ...                            ...    ...            ...
# 1327                             6      1              1
# 1328                             6      1              1
# 1329                             6      1              1
# 1330                             6      1              1
# 1331                             6      1              0
#
# [1332 rows x 5 columns]

# %%
model_C = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=2,
    id2label={0: 'C1', 1: 'C2'},
    label2id={'C1': 0, 'C2': 1}
)

model_C = model_C.to(device)
print(f"Модель инициализирована")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at sberbank-ai/ruBert-large and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Модель инициализирована

# %%
train_texts, val_texts, train_labels, val_labels = [],[],[],[]
for i in range(len(df_C)):
    if df_C['train_or_test'][i] == 1:
        train_texts.append(df_C['fragment'][i])
        train_labels.append(df_C['label'][i])
        
    else:
        val_texts.append(df_C['fragment'][i])
        val_labels.append(df_C['label'][i])

train_dataset = CEFRDataset(train_texts, train_labels, tokenizer)
val_dataset = CEFRDataset(val_texts, val_labels, tokenizer)


print(f"Обучающая выборка: {len(train_texts)}")
print(f"Валидационная выборка: {len(val_texts)}")
# Out:
# Обучающая выборка: 1057
# Валидационная выборка: 275

# %%
trainer = Trainer(
    model=model_C,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

# %%
train_start_time = time.time()
trainer.train()
train_time = time.time() - train_start_time
print(f"Обучение завершено за {train_time:.2f} секунд ({timedelta(seconds=int(train_time))})")
# Out:
#     <div>
#
#       <progress value='399' max='399' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [399/399 01:56, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.387100</td>
#       <td>0.338489</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.234800</td>
#       <td>0.205308</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.157700</td>
#       <td>0.267485</td>
#     </tr>
#   </tbody>
# </table><p>
# Обучение завершено за 117.24 секунд (0:01:57)

# %%
true_labels, predictions = evaluate_model(model_C, val_dataset, device)

accuracy = accuracy_score(true_labels, predictions)
f1_micro = f1_score(true_labels, predictions, average="micro")
f1_macro = f1_score(true_labels, predictions, average="macro")
f1_weighted = f1_score(true_labels, predictions, average="weighted")
mae = mean_absolute_error(true_labels, predictions)

print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Micro: {f1_micro:.4f}")
print(f"F1 Macro: {f1_macro:.4f}")
print(f"F1 Weighted: {f1_weighted:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# Accuracy: 0.9309
# F1 Micro: 0.9309
# F1 Macro: 0.8016
# F1 Weighted: 0.9268
# MAE: 0.0691

# %%
cm = confusion_matrix(true_labels, predictions)

fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(cm, cmap='Blues')

ax.set_xticks(range(2))
ax.set_yticks(range(2))
ax.set_xticklabels(['C1', 'C2'])
ax.set_yticklabels(['C1', 'C2'])

for i in range(2):
    for j in range(2):
        ax.text(j, i, cm[i, j], ha='center', va='center')

plt.xlabel('Предсказанные')
plt.ylabel('Истинные')
plt.title('Матрица ошибок')
plt.colorbar(im)
plt.show()

# %%
print(f"{accuracy:.4f}\n{f1_micro:.4f}\n{f1_macro:.4f}\n{f1_weighted:.4f}\n{mae:.4f}\n{train_time:.2f}")
# Out:
# 0.9309
# 0.9309
# 0.8016
# 0.9268
# 0.0691
# 117.24

# %% [markdown]
# # Двухэтапная классификация

# %%
df
# Out:
#                                                fragment  \
# 0     Весной, летом и осенью почти каждую субботу он...
# 1     Все говорят, что мама хорошая хозяйка. А ещё н...
# 2     На каждой двери красные плакаты и красные фона...
# 3     Я считаю деньги, в час обедаю в кафе, а потом ...
# 4     Магазин «Чёрный квадрат» открывается в 9 часов...
# ...                                                 ...
# 7317  Утечка мозгов стала ключевым трендом междунаро...
# 7318  По оценкам менеджеров «Промы», такая ситуация ...
# 7319  Но это не мы, а техно-мемы заполоняют мир благ...
# 7320  Mapillary использует программное обеспечение д...
# 7321  Новое роботакси, разрабатываемое Маском, сможе...
#
#       textbook-assigned cefr level  label  train_or_test
# 0                                1      1              1
# 1                                1      1              0
# 2                                1      1              1
# 3                                1      1              1
# 4                                1      1              0
# ...                            ...    ...            ...
# 7317                             6      6              1
# 7318                             6      6              1
# 7319                             6      6              1
# 7320                             6      6              1
# 7321                             6      6              0
#
# [7322 rows x 4 columns]

# %%
df['label'] = df['label']-1

# %%
df
# Out:
#                                                fragment  \
# 0     Весной, летом и осенью почти каждую субботу он...
# 1     Все говорят, что мама хорошая хозяйка. А ещё н...
# 2     На каждой двери красные плакаты и красные фона...
# 3     Я считаю деньги, в час обедаю в кафе, а потом ...
# 4     Магазин «Чёрный квадрат» открывается в 9 часов...
# ...                                                 ...
# 7317  Утечка мозгов стала ключевым трендом междунаро...
# 7318  По оценкам менеджеров «Промы», такая ситуация ...
# 7319  Но это не мы, а техно-мемы заполоняют мир благ...
# 7320  Mapillary использует программное обеспечение д...
# 7321  Новое роботакси, разрабатываемое Маском, сможе...
#
#       textbook-assigned cefr level  label  train_or_test
# 0                                1      0              1
# 1                                1      0              0
# 2                                1      0              1
# 3                                1      0              1
# 4                                1      0              0
# ...                            ...    ...            ...
# 7317                             6      5              1
# 7318                             6      5              1
# 7319                             6      5              1
# 7320                             6      5              1
# 7321                             6      5              0
#
# [7322 rows x 4 columns]

# %%
train_texts, val_texts, train_labels, val_labels = train_test_split(
    df['fragment'].values,
    df['label'].values,
    test_size=0.2,
    random_state=42,
    stratify=df['label']
)
val_dataset = CEFRDataset(val_texts, val_labels, tokenizer)

# %%
true_labels, preds = evaluate_model(model, val_dataset, device)

# %%
labels=[]
i = 0
for pred, text in zip(preds, val_texts):
    if pred == 1:
        _, predictions = evaluate_model(model_A, [val_dataset[i]], device)
        labels.append(predictions[0])
    elif pred == 2:
        _, predictions = evaluate_model(model_B, [val_dataset[i]], device)
        labels.append(predictions[0]+2)
    else:
        _, predictions = evaluate_model(model_C, [val_dataset[i]], device)
        labels.append(predictions[0]+4)
    i+=1
    # print(predictions[0], len(labels))

# %%
accuracy = accuracy_score(true_labels, labels)
f1_micro = f1_score(true_labels, labels, average="micro")
f1_macro = f1_score(true_labels, labels, average="macro")
f1_weighted = f1_score(true_labels, labels, average="weighted")
mae = mean_absolute_error(true_labels, labels)

print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Micro: {f1_micro:.4f}")
print(f"F1 Macro: {f1_macro:.4f}")
print(f"F1 Weighted: {f1_weighted:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# Accuracy: 0.6259
# F1 Micro: 0.6259
# F1 Macro: 0.6099
# F1 Weighted: 0.6189
# MAE: 0.4785

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report
print(classification_report(true_labels, labels))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.81      0.75      0.78       153
#            2       0.72      0.34      0.47       227
#            3       0.60      0.71      0.65       475
#            4       0.61      0.58      0.59       343
#            5       0.59      0.72      0.65       237
#            6       0.52      0.53      0.52        30
#
#     accuracy                           0.63      1465
#    macro avg       0.64      0.61      0.61      1465
# weighted avg       0.64      0.63      0.62      1465
