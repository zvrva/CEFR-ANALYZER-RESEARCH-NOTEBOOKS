# %%
import requests
import pandas as pd
import time
import re
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score, mean_absolute_error
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

# %%
def cefr_to_numeric(level: str) -> int:
    mapping = {"A1": 1, "A2": 2, "B1": 3, "B2": 4, "C1": 5, "C2": 6, "Не определен": "Не определен", "А1": 1,"А2": 2, "Б1": 3, "Б2": 4, "С1": 5, "С2": 6}
    return mapping.get(level, 0)


def numeric_to_cefr(value: int) -> str:
    mapping = {1: "A1", 2: "A2", 3: "B1", 4: "B2", 5: "C1", 6: "C2", "Не определен": "Не определен"}
    return mapping.get(value, "Не определен")

# %%
def extract_cefr_level(response: str) -> str:
    if not response:
        return "Ошибка"
    
    response_upper = response.upper().strip()
    levels = ["A1", "A2", "B1", "B2", "C1", "C2", "А1", "А2", "Б1", "Б2", "С1", "С2"]
    
    for level in levels:
        if level in response_upper:
            return level
    
    return "Не определен"

# %%
class RussianOllamaClient:
    def __init__(self, model_name="llama3"):
        self.model_name = model_name
        self.base_url = "http://localhost:11434"
        print(f"Используем модель: {model_name}")
    
    def make_request(self, prompt: str, max_tokens: int = 100) -> str:
        data = {
            "model": self.model_name,
            "prompt": prompt,
            "stream": False,
            "options": {
                "temperature": 0.3,
                "num_predict": max_tokens
            }
        }
        
        try:
            response = requests.post(
                f"{self.base_url}/api/generate", 
                json=data, 
                timeout=120
            )
            
            if response.status_code == 200:
                result = response.json()
                return result['response']
            else:
                print(f"❌ Ошибка {response.status_code}")
                return ""
                
        except Exception as e:
            print(f"❌ Исключение: {e}")
            return ""

# %%
client = RussianOllamaClient("llama3:8b")  
    
test_response = client.make_request("Скажи 'тест пройден'")
if test_response:
    print("✅ Модель работает")
else:
    print("❌ Модель не отвечает")
# Out:
# Используем модель: llama3:8b
# ✅ Модель работает

# %%
df = pd.read_csv('ru_cefr_short.csv')
df
# Out:
#                                                fragment  \
# 0     Весной, летом и осенью почти каждую субботу он...
# 1     Все говорят, что мама хорошая хозяйка. А ещё н...
# 2     На каждой двери красные плакаты и красные фона...
# 3     Я считаю деньги, в час обедаю в кафе, а потом ...
# 4     Магазин «Чёрный квадрат» открывается в 9 часов...
# ...                                                 ...
# 7317  Утечка мозгов стала ключевым трендом междунаро...
# 7318  По оценкам менеджеров «Промы», такая ситуация ...
# 7319  Но это не мы, а техно-мемы заполоняют мир благ...
# 7320  Mapillary использует программное обеспечение д...
# 7321  Новое роботакси, разрабатываемое Маском, сможе...
#
#       textbook-assigned cefr level
# 0                                1
# 1                                1
# 2                                1
# 3                                1
# 4                                1
# ...                            ...
# 7317                             6
# 7318                             6
# 7319                             6
# 7320                             6
# 7321                             6
#
# [7322 rows x 2 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df['fragment'], df['textbook-assigned cefr level'], test_size=0.2, random_state=42)

print(f"Обучающая выборка: {len(X_train)}")
print(f"Тестовая выборка: {len(X_test)}")
# Out:
# Обучающая выборка: 5857
# Тестовая выборка: 1465

# %%
texts_to_test = X_test.tolist()
levels_to_test = y_test.tolist()

len(texts_to_test) == len(levels_to_test)
# Out:
# True

# %%
def create_zero_shot_prompt(text):
    return f'''Ты - эксперт по русскому языку как иностранному (РКИ). Определи уровень CEFR текста на основе следующих критериев:

A1: Очень частотная повседневная лексика, простые предложения, базовые падежи. Глаголы движения без приставок (идти-ходить, ехать-ездить). Предложный падеж с предлогом о, дательный падеж (кому), родительный падеж (нет урока, тетрадь студента). Конструкции с предлогами из, для, без, около, после. Простые предложения или короткие сложноподчиненные с союзами что, потому что. Конструкции типа ""мне холодно"". Достижение уровня для удовлетворения элементарных коммуникативных потребностей.

A2: Частотная лексика, глаголы движения с приставками (по-, при-, в-, вы-, пере-, под-, до-, об-, за-) в прошедшем и будущем времени. Фразы с ""ещё"" и ""уже"", формы императива, простые случаи косвенной речи, возвратные глаголы и местоимения. Сложносочиненные предложения с союзами и, или, а, но. Короткие сложноподчиненные предложения с придаточными времени, условия, цели (когда, если, чтобы), предложения с союзным словом ""который"". Расширение сферы межличностного общения в стандартных ситуациях повседневной жизни.

B1: Абстрактная лексика, причастия/деепричастия, причастные и деепричастные обороты, формы пассива. Глаголы движения (бежать-бегать, лететь-летать и др.) с приставками. Собирательные числительные (двое), неопределенные местоимения (кто-то), сравнительная и превосходная степень прилагательных. Сложносочиненные предложения с союзами только, однако, либо. Сложноподчиненные предложения со словами там, туда, оттуда, из-за, благодаря, несмотря на, хотя, для того чтобы, в то время как, пока. Условные конструкции ""если бы"". Подготовка к обучению в вузах, поддержание социально-делового общения.

B2: Стилистически окрашенная лексика, лексика научного и официально-делового стиля, фразеология. Активно используются деепричастные обороты, страдательный залог, причастия, разнообразные союзы и предлоги, сложная структура предложений. Предложения с безличными глаголами (хочется), нетипичные случаи выражения субъекта и предиката, инфинитив в позиции подлежащего. Конструкции с выражением субъективной оценки: частицы пусть, конструкции с должен, вынужден. Конструкции с наречиями негде, некогда, предложения с предлогами при, вместо, ради. Обучение в вузе, использование различных стилей языка, свободное понимание СМИ.

C1: Сложная лексика, длинные предложения с придаточными, высокая степень номинализации, возможна устаревшая или книжная лексика. Всё многообразие типов придаточных предложений. Длинные предложения с несколькими придаточными и сложными союзами: как вдруг, в то время как, после того как, с тех пор как, благодаря тому что, вследствие того что, поскольку, так что, с тем чтобы, будто, словно. Предложения с предикатным, присловным и противопоставительным отрицанием. Неопределённо-личные и безличные конструкции. Владение различными стилями языка, способность воспринимать информацию во всей полноте в различных ситуациях общения.

C2: Научный стиль, идиомы, сложные синтаксические конструкции. Синтаксические модели выражения логической связи: что является чем, представляет собой, относится к, предназначено для, обозначается как, ведет к чему, состоит из чего, из чего следует что, характеризуется чем. Устойчивые обороты речи, идиомы. Владение языком на профессиональном уровне, включая преподавание РКИ и научно-исследовательскую работу.

Текст для анализа: ""{text}""

Верни ТОЛЬКО уровень CEFR (A1, A2, B1, B2, C1, C2) без дополнительных объяснений.'''

# %%
model_responses = []
predicted_levels = []

print(f"Анализируем {len(texts_to_test)} текстов...")

for i in range(len(texts_to_test)):
    text, real_level = texts_to_test[i], levels_to_test[i]
    
    print(f"\nТекст {i+1}/{len(X_test)}: {text[:80]}...")
    
    prompt = create_zero_shot_prompt(text)
    response = client.make_request(prompt)
    level = extract_cefr_level(response)
    
    print(f"    Реальный уровень {numeric_to_cefr(real_level)}")
    print(f"    Предсказание модели: {level}")

    predicted_levels.append(cefr_to_numeric(level))
    model_responses.append(response)
# Out:
# Анализируем 1465 текстов...
#
# Текст 1/1465: Организм после бани легче переносит физические нагрузки, интенсивную работу, луч...
#     Реальный уровень B1
#     Предсказание модели: B2
#
# Текст 2/1465: Через полстолетия в моду входит не просто стройность, а настоящая худоба. В шест...
#     Реальный уровень A2
#     Предсказание модели: Б1
#
# Текст 3/1465: Одного беглого взгляда на кривую саврасовскую берёзку хватит, чтобы вспомнить ур...
#     Реальный уровень B2
#     Предсказание модели: B2
#
# Текст 4/1465: С развитием науки в МГУ открывались новые и новые факультеты, например, факульте...
#     Реальный уровень B1
#     Предсказание модели: B2
#
# Текст 5/1465: Обычно первые числа мая объявляются нерабочими, поэтому люди гуляют по городу ил...
#     Реальный уровень B2
#     Предсказание модели: B2
#
# Текст 6/1465: «Проекты о путешествиях Познера и Урганта», Первый канал. Первая совместная рабо...
#     Реальный уровень B1
#     Предсказание модели: B2
#
# Текст 7/1465: Телевидение вошло в наши дома очень скромно: через маленькие экраны, линзы с вод...
#     Реальный уровень C1
#     Предсказание модели: B1
#
# Текст 8/1465: Завтра утром я встану в 7 часов, приму душ, позавтракаю и поеду на работу. Я буд...
#     Реальный уровень A2
#     Предсказание модели: A2
#
# Текст 9/1465: Он был не только любимым артистом, он был любящим мужем и отцом. (У него была се...
#     Реальный уровень A2
#     Предсказание модели: Б1
#
# Текст

#     Реальный уровень B1
#     Предсказание модели: B1
#
# Текст 1405/1465: Характерная черта немецких школ — небольшое количество иностранцев, что объясняе...
#     Реальный уровень B2
#     Предсказание модели: B2
#
# Текст 1406/1465: Вечером мы с друзьями устроим вечеринку или пойдём на дискотеку. А может быть, я...
#     Реальный уровень A2
#     Предсказание модели: B1
#
# Текст 1407/1465: Мой папа — гитарист. У него есть брат. Это мой дядя. Его зовут Сергей. Он бизнес...
#     Реальный уровень A1
#     Предсказание модели: А2
#
# Текст 1408/1465: Обычно люди представляют себе радиацию как яд, который просачивается всюду и зар...
#     Реальный уровень C2
#     Предсказание модели: Б1
#
# Текст 1409/1465: Музыкой начала заниматься, когда мне было 5 лет. Я участвовала в телевизионной п...
#     Реальный уровень A2
#     Предсказание модели: B1
#
# Текст 1410/1465: Ну, во-первых, у нас было очень уютное купе, где мы не только спали, но и пили ч...
#     Реальный уровень A1
#     Предсказание модели: B1
#
# Текст 1411/1465: Спрос на представителей данной профессии растёт с каждым годом и в ближайшем буд...
#     Реальный уровень C1
#     Предсказание модели: B2
#
# Текст 1412/1465: Смешное, полезное и интересное изобретение придумала и тут же запатентовала мале...
#     Реальный уровень B1
#     Предсказание модели: A2
#
# Текст 1413/1465: В Суздале тоже было холодно, но друзья с удовольствием гуляли, много фотографиро...
#     Реальный уровень A1
#     Предсказание модели: B1
#
# Текст 1414/1465: В этот день во многих городах России прошли парады и праздничные демонстрации, с...
#     Реальный уровень B1
#     Предсказание модели: B1
#
# Текст 1415/1465: Эта книга рассказывает читателям удивительную историю жизни легенды советского с...
#     Реальный уровень B1
#     Предсказание модели: B1
#
# Текст 1416/1465: Ему нравятся экономика и математика, он любит решать задачи, но ему не нравится ...
#     Реальный уровень A1
#     Предсказание модели: B1
#
# Текст 1417/1465: Это мой друг. Это моя подруга. Это мой дом. Это моё место. Это моя комната. Это ...
#     Реальный уровень A1
#     Предсказание модели: A2
#
# Текст 1418/1465: Теперь, честно говоря, смотреть программу не хочется. Вопросы в большинстве своё...
#     Реальный уровень B2
#     Предсказание модели: Б1
#
# Текст 1419/1465: И сейчас он делает операции, читает лекции студентам, пишет книги и регулярно да...
#     Реальный уровень A2
#     Предсказание модели: B2
#
# Текст 1420/1465: Горит и кружится планета, Над нашей Родиною дым. И, значит, нам нужна одна побед...
#     Реальный уровень B1
#     Предсказание модели: B1
#
# Текст 1421/1465: Летом я поехал в деревню к бабушке. В соседней деревне живёт мой друг. Он пригла...
#     Реальный уровень B1
#     Предсказание модели: A2
#
# Текст 1422/1465: Он помнит о том, что нужно будет сохранить культуру прошлого для будущего тех, к...
#     Реальный уровень B1
#     Предсказание модели: B2
#
# Текст 1423/1465: Озёрная вода чистая и прозрачная. Её цвет зелёно-синий, но он часто меняется, на...
#     Реальный уровень B2
#     Предсказание модели: B2
#
# Текст 1424/1465: Во многих детских садах дети изучают иностранные языки, например, английский или...
#     Реальный уровень B1
#     Предсказание модели: А2
#
# Текст 1425/1465: Максим: В старой квартире у вас на кухне висели часы, которые мы вам подарили. А...
#     Реальный уровень A2
#     Предсказание модели: B1
#
# Текст 1426/1465: У нас есть сын. Его зовут Дима. Он школьник. Я думаю, он мало читает и много смо...
#     Реальный уровень A1
#     Предсказание модели: A2
#
# Текст 1427/1465: Оли долго аплодировали, бросали цветы на сцену и не хотели уходить из театра. С ...
#     Реальный уровень B1
#     Предсказание модели: Б1
#
# Текст 1428/1465: В 1859 году строительство храма закончилось и началась работа художников, котора...
#     Реальный уровень A2
#     Предсказание модели: B1
#
# Текст 1429/1465: Это трудно, но ничего. Изучать русский язык тоже трудно, но весело и интересно. ...
#     Реальный уровень A1
#     Предсказание модели: B1
#
# Текст 1430/1465: Поэтому однажды она решила изменить свою жизнь: она рассталась с мужем, взяла ма...
#     Реальный уровень B1
#     Предсказание модели: B2
#
# Текст 1431/1465: Откуда это — понятно: до войны было общеизвестное танго «Утомлённое солнце». Оно...
#     Реальный уровень C1
#     Предсказание модели: B2
#
# Текст 1432/1465: Турки очень любят кофе, но на завтрак пьют чай с мёдом. Марокко: завтрак без апе...
#     Реальный уровень A1
#     Предсказание модели: B2
#
# Текст 1433/1465: Сегодня часто думают, что пиджак и галстук значат, что у вас есть хорошая работа...
#     Реальный уровень A1
#     Предсказание модели: B1
#
# Текст 1434/1465: Миша часто выпускает меня, и я летаю по комнате. Крылья у меня большие и, когда ...
#     Реальный уровень A2
#     Предсказание модели: B1
#
# Текст 1435/1465: Профессия логиста стала одной из самых нужных в наши дни. Сегодня наблюдается пе...
#     Реальный уровень C1
#     Предсказание модели: Б1
#
# Текст 1436/1465: км, австралийской пустыне. Кстати, не по этой ли причине большая часть пустынь г...
#     Реальный уровень C1
#     Предсказание модели: B2
#
# Текст 1437/1465: Благодаря таким картам мы покупаем больше кофе, потому что хотим как можно скоре...
#     Реальный уровень B1
#     Предсказание модели: Б1
#
# Текст 1438/1465: Потом появились на свет Вера, Надежда, Варвара, Николай, Иван. Самая младшая сес...
#     Реальный уровень B1
#     Предсказание модели: A2
#
# Текст 1439/1465: Здесь в 1882 году вместе с семьёй поселился Лев Николаевич Толстой. В то время о...
#     Реальный уровень B2
#     Предсказание модели: B1
#
# Текст 1440/1465: Некоторые говорят, что халяву ловят в банку, а после прихода препода эту банку о...
#     Реальный уровень B2
#     Предсказание модели: B2
#
# Текст 1441/1465: Она является не просто дистрибьютором, но и самым крупным ботлером — изготовител...
#     Реальный уровень C1
#     Предсказание модели: B1
#
# Текст 1442/1465: В 6 лет у Лауры уже была своя лодка, на которой она плавала каждый день после за...
#     Реальный уровень A2
#     Предсказание модели: A2
#
# Текст 1443/1465: В университете изучают много теории и совсем мало занимаются практикой. В резуль...
#     Реальный уровень B1
#     Предсказание модели: B2
#
# Текст 1444/1465: Остановившись, неожиданно видишь почти степной чернозём. Это ополье, житница сев...
#     Реальный уровень C1
#     Предсказание модели: B2
#
# Текст 1445/1465: Когда я подошёл к двери дома, я понял, что забыл или потерял ключи и не могу вой...
#     Реальный уровень B1
#     Предсказание модели: B1
#
# Текст 1446/1465: Но как раз у северных народов (у эвенков или эскимосов) бороды практически нет. ...
#     Реальный уровень B1
#     Предсказание модели: B1
#
# Текст 1447/1465: Концертов с «живыми голосами», не под фонограмму. Молодёжных передач, например, ...
#     Реальный уровень B2
#     Предсказание модели: B2
#
# Текст 1448/1465: В 1993 году его новый фильм «Урга» признали лучшим европейским фильмом года: он ...
#     Реальный уровень C1
#     Предсказание модели: B1
#
# Текст 1449/1465: Православные верят, что Христос родился от Девы Марии и принял страшную смерть, ...
#     Реальный уровень B2
#     Предсказание модели: B1
#
# Текст 1450/1465: Именно поэтому красный цвет был символом спасения от злых сил ночи и темноты. Од...
#     Реальный уровень B2
#     Предсказание модели: Б1
#
# Текст 1451/1465: Во время игры Боргов очень серьёзен и холоден, не показывает никаких эмоций. Он ...
#     Реальный уровень B1
#     Предсказание модели: B1
#
# Текст 1452/1465: Одним из начинаний царя Петра I было научное изучение географии России и, в перв...
#     Реальный уровень B2
#     Предсказание модели: Б1
#
# Текст 1453/1465: «Киборг — это просто попытка назвать инвалидность другим словом, но я реально ве...
#     Реальный уровень C2
#     Предсказание модели: B2
#
# Текст 1454/1465: «С Новым счастьем!» Если вас пригласили на праздник Нового года в русскую семью,...
#     Реальный уровень B1
#     Предсказание модели: A2
#
# Текст 1455/1465: Человек, знающий с детства или долгие годы о своих проблемах с кровяным давление...
#     Реальный уровень B1
#     Предсказание модели: Б1
#
# Текст 1456/1465: Раньше дети часто работали, а в наше время они не могут работать, но хорошо знаю...
#     Реальный уровень A1
#     Предсказание модели: Б1
#
# Текст 1457/1465: Нет необходимости ненавидеть другие народы, потому что ты патриот. Между патриот...
#     Реальный уровень B2
#     Предсказание модели: B1
#
# Текст 1458/1465: Музыкант выступил как исполнитель и композитор. Шостакович писал оперную и балет...
#     Реальный уровень B2
#     Предсказание модели: B1
#
# Текст 1459/1465: В субботу Мария, Клара, Том были на экскурсии «Пушкин в Москве». Это была очень ...
#     Реальный уровень A1
#     Предсказание модели: B1
#
# Текст 1460/1465: Только в 1988 году роман «Доктор Живаго» был впервые опубликован в России. В 198...
#     Реальный уровень B1
#     Предсказание модели: Б1
#
# Текст 1461/1465: Лишний вес не только вреден для здоровья, но и опасен в случае аварии. К такому ...
#     Реальный уровень B2
#     Предсказание модели: B1
#
# Текст 1462/1465: Русские люди встречают Новый год ночью, в 12 часов, с 31 (тридцать первого) дека...
#     Реальный уровень A1
#     Предсказание модели: A2
#
# Текст 1463/1465: Во второй раз можно париться уже на верхней полке. Обычно сначала я парю веником...
#     Реальный уровень B1
#     Предсказание модели: A2
#
# Текст 1464/1465: Несмотря на то что многие годы павловопосадский платок считался предметом женско...
#     Реальный уровень B2
#     Предсказание модели: Б1
#
# Текст 1465/1465: Какой самый опасный вид спорта? Может быть, бокс или хоккей? Да, эти виды спорта...
#     Реальный уровень A1
#     Предсказание модели: Б1

# %%
df_pred = pd.DataFrame(columns=['text', 'real_level', 'predicted_level', 'model_response'])
df_pred['text'] = texts_to_test
df_pred['real_level'] = levels_to_test
df_pred['predicted_level'] = predicted_levels
df_pred['model_response'] = model_responses
df_pred
# Out:
#                                                    text  real_level  \
# 0     Организм после бани легче переносит физические...           3
# 1     Через полстолетия в моду входит не просто стро...           2
# 2     Одного беглого взгляда на кривую саврасовскую ...           4
# 3     С развитием науки в МГУ открывались новые и но...           3
# 4     Обычно первые числа мая объявляются нерабочими...           4
# ...                                                 ...         ...
# 1460  Лишний вес не только вреден для здоровья, но и...           4
# 1461  Русские люди встречают Новый год ночью, в 12 ч...           1
# 1462  Во второй раз можно париться уже на верхней по...           3
# 1463  Несмотря на то что многие годы павловопосадски...           4
# 1464  Какой самый опасный вид спорта? Может быть, бо...           1
#
#       predicted_level model_response
# 0                   4             B2
# 1                   3             Б1
# 2                   4             B2
# 3                   4             B2
# 4                   4             B2
# ...               ...            ...
# 1460                3             B1
# 1461                2      Level: A2
# 1462                2      Level: A2
# 1463                3             Б1
# 1464                3             Б1
#
# [1465 rows x 4 columns]

# %%
df_pred.to_csv("zero-shot.csv", index=False)

# %%
df_pred['predicted_level'].unique()
# Out:
# array([4, 3, 2, 1])

# %%
print(f"Точность: {accuracy_score(df_pred['real_level'], df_pred['predicted_level'])}")

print(f"F1-score micro: {f1_score(df_pred['real_level'], df_pred['predicted_level'], average="micro")}")
print(f"F1-score macro: {f1_score(df_pred['real_level'], df_pred['predicted_level'], average="macro")}")
print(f"F1-score weighted: {f1_score(df_pred['real_level'], df_pred['predicted_level'], average="weighted")}")

print(f"MAE: {mean_absolute_error(df_pred['real_level'], df_pred['predicted_level'])}")
# Out:
# Точность: 0.28737201365187715
# F1-score micro: 0.28737201365187715
# F1-score macro: 0.14108811844986463
# F1-score weighted: 0.21664070389352424
# MAE: 0.9494880546075085

# %%
print(round(accuracy_score(df_pred['real_level'], df_pred['predicted_level']),4))
print(round(f1_score(df_pred['real_level'], df_pred['predicted_level'], average="micro"),4))
print(round(f1_score(df_pred['real_level'], df_pred['predicted_level'], average="macro"),4))
print(round(f1_score(df_pred['real_level'], df_pred['predicted_level'], average="weighted"),4))
print(round(mean_absolute_error(df_pred['real_level'], df_pred['predicted_level']),4))
# Out:
# 0.2874
# 0.2874
# 0.1411
# 0.2166
# 0.9495

# %%
cm = confusion_matrix(df_pred['real_level'], df_pred['predicted_level'])

fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(cm, cmap='Blues')

ax.set_xticks(range(6))
ax.set_yticks(range(6))
ax.set_xticklabels(['A1', 'A2', 'B1', 'B2', 'C1', 'C2'])
ax.set_yticklabels(['A1', 'A2', 'B1', 'B2', 'C1', 'C2'])

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        value = cm[i, j]
        ax.text(
            j, i,
            f"{value:.0f}",
            ha="center",
            va="center",
            color="white" if value > cm.max() / 2 else "black",
            fontsize=11
        )

plt.xlabel('Предсказанные')
plt.ylabel('Истинные')
plt.title('Матрица ошибок')

plt.colorbar(im)
plt.tight_layout()
plt.show()
